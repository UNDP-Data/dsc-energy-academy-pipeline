# %%
import pandas as pd
import json
import re
from pathlib import Path

def normalize(text):
    return re.sub(r"[\u202f\xa0]", " ", str(text)).strip()

def clean_title(text, prefix=None):
    text = normalize(text)
    return re.sub(prefix, "", text).strip() if prefix else text

def get_titles(df, index_col, title_col):
    return df[[index_col, title_col]].drop_duplicates().set_index(index_col)[title_col].to_dict()

def load_and_clean_data(csv_path):
    df = pd.read_csv(csv_path)
    df = df[df["Number"].notna() & df["Number"].astype(str).str.match(r"^\d+\.\d+\.\d+$")]
    df["Module Title"] = df["Module Title"].ffill()
    df["Chapter Title"] = df["Chapter Title"].ffill()
    df["Module Number"] = df["Number"].apply(lambda x: str(x).split(".")[0])
    df["Chapter Number"] = df["Number"].apply(lambda x: ".".join(str(x).split(".")[:2]))
    return df

def build_module_structure(df, module_titles, chapter_titles):
    structure = []
    for module_num in sorted(module_titles):
        module_title = clean_title(module_titles[module_num], r"^Module\s*\d+:?\s*")
        module = {
            "id": module_num,
            "title": f"Module {module_num}: {module_title}",
            "chapters": [
                {
                    "id": f"{module_num}.0",
                    "title": f"Module {module_num} Introduction",
                    "lessons": [{
                        "id": f"{module_num}.0.0",
                        "title": f"Module {module_num} Introduction"
                    }]
                }
            ]
        }

        chapter_nums = sorted(set(df[df["Module Number"] == module_num]["Chapter Number"]))
        for chapter_num in chapter_nums:
            parts = chapter_num.split(".")
            if len(parts) != 2:
                continue
            chap_short = parts[1]
            chapter_title = clean_title(chapter_titles.get(chapter_num, f"Chapter {chap_short}"), r"^Chapter\s*\d+:?\s*")

            lessons = [{
                "id": f"{chapter_num}.0",
                "title": f"Chapter {chap_short} Introduction"
            }] + [
                {
                    "id": row["Number"],
                    "title": clean_title(row["Lesson Title"])
                } for _, row in df[df["Chapter Number"] == chapter_num].iterrows()
            ] + [{
                "id": f"{chapter_num}.-1",
                "title": f"Chapter {chap_short} Outro"
            }]

            module["chapters"].append({
                "id": chapter_num,
                "title": f"Chapter {chap_short}: {chapter_title}",
                "lessons": lessons
            })

        module["chapters"].append({
            "id": f"{module_num}.-1",
            "title": f"Module {module_num} Outro",
            "lessons": [{
                "id": f"{module_num}.-1.0",
                "title": f"Module {module_num} Outro"
            }]
        })

        structure.append(module)
    return structure

def save_structure(structure, output_path):
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(structure, f, indent=2, ensure_ascii=False)
    print(json.dumps(structure, indent=2, ensure_ascii=False))
    print(f"\n✅ Module structure saved to: {output_path}")

def generate_structure():
    csv_path = Path("../03_Inputs/Test Data/SEA Table of Contents.csv")
    output_path = Path("../04_Outputs/Test/module_structure.json")

    df = load_and_clean_data(csv_path)
    module_titles = get_titles(df, "Module Number", "Module Title")
    chapter_titles = get_titles(df, "Chapter Number", "Chapter Title")
    structure = build_module_structure(df, module_titles, chapter_titles)
    save_structure(structure, output_path)

generate_structure()
# Out:
# [
#   {
#     "id": "1",
#     "title": "Module 1: Intro to Sustainable Energy for Development",
#     "chapters": [
#       {
#         "id": "1.0",
#         "title": "Module 1 Introduction",
#         "lessons": [
#           {
#             "id": "1.0.0",
#             "title": "Module 1 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "1.1",
#         "title": "Chapter 1: Introduction to Energy Systems",
#         "lessons": [
#           {
#             "id": "1.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "1.1.1",
#             "title": "Introduction to the Energy for Development pathway"
#           },
#           {
#             "id": "1.1.2",
#             "title": "The Sustainable Energy Landscape"
#           },
#           {
#             "id": "1.1.3",
#             "title": "The Path to Achieving Universal Energy Access by 2030"
#           },
#           {
#             "id": "1.1.4",
#             "title": "Financing the Sustainable Energy Revolution"
#           },
#           {
#             "id": "1.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "1.2",
#         "title": "Chapter 2: Approaches, Methods and Tools for Strategic Innovation",
#         "lessons": [
#           {
#             "id": "1.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "1.2.1",
#             "title": "Access to electricity and clean cooking (SDG 7.1)"
#           },
#           {
#             "id": "1.2.2",
#             "title": "Renewable energy (SDG 7.2)"
#           },
#           {
#             "id": "1.2.3",
#             "title": "Energy Efficiency (SDG 7.3)"
#           },
#           {
#             "id": "1.2.4",
#             "title": "Integrated Approach"
#           },
#           {
#             "id": "1.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "1.3",
#         "title": "Chapter 3: Regional Perspective",
#         "lessons": [
#           {
#             "id": "1.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "1.3.1",
#             "title": "Latin America and the Caribbean"
#           },
#           {
#             "id": "1.3.2",
#             "title": "Eastern Europe and Central Asia"
#           },
#           {
#             "id": "1.3.3",
#             "title": "Arab States"
#           },
#           {
#             "id": "1.3.4",
#             "title": "Asia-Pacific"
#           },
#           {
#             "id": "1.3.5",
#             "title": "Africa"
#           },
#           {
#             "id": "1.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "1.4",
#         "title": "Chapter 4: The Sustainable Energy Academy",
#         "lessons": [
#           {
#             "id": "1.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "1.4.1",
#             "title": "The Sustainable Energy Academy: Modules 2-8"
#           },
#           {
#             "id": "1.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "1.-1",
#         "title": "Module 1 Outro",
#         "lessons": [
#           {
#             "id": "1.-1.0",
#             "title": "Module 1 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "2",
#     "title": "Module 2: Energy Access and Inclusive Energy Services",
#     "chapters": [
#       {
#         "id": "2.0",
#         "title": "Module 2 Introduction",
#         "lessons": [
#           {
#             "id": "2.0.0",
#             "title": "Module 2 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "2.1",
#         "title": "Chapter 1: Topic Overview and Background",
#         "lessons": [
#           {
#             "id": "2.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "2.1.1",
#             "title": "Energy Access - Core Concepts"
#           },
#           {
#             "id": "2.1.2",
#             "title": "Sustainable Energy to power development"
#           },
#           {
#             "id": "2.1.3",
#             "title": "Energy Poverty and Fuel Poverty"
#           },
#           {
#             "id": "2.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "2.2",
#         "title": "Chapter 2: Current Status, Trends and Barriers to Energy Access",
#         "lessons": [
#           {
#             "id": "2.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "2.2.1",
#             "title": "The Energy Access Landscape"
#           },
#           {
#             "id": "2.2.2",
#             "title": "Status and Trends"
#           },
#           {
#             "id": "2.2.3",
#             "title": "Challenges for universal energy access"
#           },
#           {
#             "id": "2.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "2.3",
#         "title": "Chapter 3: Bridging the Energy Access Gap",
#         "lessons": [
#           {
#             "id": "2.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "2.3.1",
#             "title": "An Intersectional Approach"
#           },
#           {
#             "id": "2.3.2",
#             "title": "Technological Solutions"
#           },
#           {
#             "id": "2.3.3",
#             "title": "Financing Mechanisms"
#           },
#           {
#             "id": "2.3.4",
#             "title": "Policy Frameworks"
#           },
#           {
#             "id": "2.3.5",
#             "title": "Collaborative Multi-Stakeholder Partnerships"
#           },
#           {
#             "id": "2.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "2.-1",
#         "title": "Module 2 Outro",
#         "lessons": [
#           {
#             "id": "2.-1.0",
#             "title": "Module 2 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "3",
#     "title": "Module 3: Just Energy Transition",
#     "chapters": [
#       {
#         "id": "3.0",
#         "title": "Module 3 Introduction",
#         "lessons": [
#           {
#             "id": "3.0.0",
#             "title": "Module 3 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "3.1",
#         "title": "Chapter 1: Introduction to the Energy Transition Landscape",
#         "lessons": [
#           {
#             "id": "3.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "3.1.1",
#             "title": "The Energy Transition In Context"
#           },
#           {
#             "id": "3.1.2",
#             "title": "Unpacking The Concept Of A Just Energy Transition"
#           },
#           {
#             "id": "3.1.3",
#             "title": "Key Challenges In The Global South"
#           },
#           {
#             "id": "3.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "3.2",
#         "title": "Chapter 2: Ensuring a Just Transition for Workers and Affected Communities",
#         "lessons": [
#           {
#             "id": "3.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "3.2.1",
#             "title": "Human rights and socio-economic impacts"
#           },
#           {
#             "id": "3.2.2",
#             "title": "Worker Retraining and Employment Disparities"
#           },
#           {
#             "id": "3.2.3",
#             "title": "Social Safety Nets and Income Support"
#           },
#           {
#             "id": "3.2.4",
#             "title": "Community-led sustainable energy projects and community-based solutions"
#           },
#           {
#             "id": "3.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "3.3",
#         "title": "Chapter 3: A JET that Preserves Nature and Catalyzes Economic Growth",
#         "lessons": [
#           {
#             "id": "3.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "3.3.1",
#             "title": "Critical Minerals and Materials"
#           },
#           {
#             "id": "3.3.2",
#             "title": "Environmental Concerns of Clean Energy Technology Deployment"
#           },
#           {
#             "id": "3.3.3",
#             "title": "Advancing the Value Chain"
#           },
#           {
#             "id": "3.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "3.4",
#         "title": "Chapter 4: Strategic Governance and Partnership Models for Just Energy Transitions",
#         "lessons": [
#           {
#             "id": "3.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "3.4.1",
#             "title": "Governance Strategies for a Just Energy Transition"
#           },
#           {
#             "id": "3.4.2",
#             "title": "Importance of Proactive Planning and Strategic Foresight"
#           },
#           {
#             "id": "3.4.3",
#             "title": "Just Energy Transition Partnerships (JET-P)"
#           },
#           {
#             "id": "3.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "3.-1",
#         "title": "Module 3 Outro",
#         "lessons": [
#           {
#             "id": "3.-1.0",
#             "title": "Module 3 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "4",
#     "title": "Module 4: Sustainable Energy Finance",
#     "chapters": [
#       {
#         "id": "4.0",
#         "title": "Module 4 Introduction",
#         "lessons": [
#           {
#             "id": "4.0.0",
#             "title": "Module 4 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "4.1",
#         "title": "Chapter 1: Introduction to Sustainable Energy Finance and Market Dynamics",
#         "lessons": [
#           {
#             "id": "4.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "4.1.1",
#             "title": "Fundamentals of Sustainable Energy Financing"
#           },
#           {
#             "id": "4.1.2",
#             "title": "The Global Energy Investment Landscape of Energy Investments"
#           },
#           {
#             "id": "4.1.3",
#             "title": "An Overview of Sustainable Energy Market Dynamics"
#           },
#           {
#             "id": "4.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "4.2",
#         "title": "Chapter 2: Public Sector and Sustainable Energy Finance",
#         "lessons": [
#           {
#             "id": "4.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "4.2.1",
#             "title": "Role of Public Sector in Sustainable Energy Finance"
#           },
#           {
#             "id": "4.2.2",
#             "title": "Financial Health Policies and Regulation"
#           },
#           {
#             "id": "4.2.3",
#             "title": "The Energy Subsidy Reform"
#           },
#           {
#             "id": "4.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "4.3",
#         "title": "Chapter 3: Scaling Up Private Sector Investment in Sustainable Energy",
#         "lessons": [
#           {
#             "id": "4.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "4.3.1",
#             "title": "Private Sector Investment in Sustainable Energy"
#           },
#           {
#             "id": "4.3.2",
#             "title": "Risk Mitigation Strategies"
#           },
#           {
#             "id": "4.3.3",
#             "title": "Blended Finance"
#           },
#           {
#             "id": "4.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "4.4",
#         "title": "Chapter 4: Innovative Financial Instruments and Tools for Renewable Energy",
#         "lessons": [
#           {
#             "id": "4.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "4.4.1",
#             "title": "Thematic Bonds (Public and Corporate)"
#           },
#           {
#             "id": "4.4.2",
#             "title": "Debt Swaps (Debt for Energy, D4E)"
#           },
#           {
#             "id": "4.4.3",
#             "title": "Carbon Financing"
#           },
#           {
#             "id": "4.4.4",
#             "title": "Emerging Technologies: AI-Powered and Digital Financing Solutions"
#           },
#           {
#             "id": "4.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "4.5",
#         "title": "Chapter 5: Cross-Sectional Issues in Sustainable Energy Finance",
#         "lessons": [
#           {
#             "id": "4.5.0",
#             "title": "Chapter 5 Introduction"
#           },
#           {
#             "id": "4.5.1",
#             "title": "Partnerships for Sustainable Energy Investments"
#           },
#           {
#             "id": "4.5.2",
#             "title": "Gender Equality And Sustainable Energy Finance"
#           },
#           {
#             "id": "4.5.3",
#             "title": "Regional Priorities"
#           },
#           {
#             "id": "4.5.-1",
#             "title": "Chapter 5 Outro"
#           }
#         ]
#       },
#       {
#         "id": "4.-1",
#         "title": "Module 4 Outro",
#         "lessons": [
#           {
#             "id": "4.-1.0",
#             "title": "Module 4 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "5",
#     "title": "Module 5: Energy Governance for a Just Energy Transition",
#     "chapters": [
#       {
#         "id": "5.0",
#         "title": "Module 5 Introduction",
#         "lessons": [
#           {
#             "id": "5.0.0",
#             "title": "Module 5 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "5.1",
#         "title": "Chapter 1: An Overview of Energy Governance",
#         "lessons": [
#           {
#             "id": "5.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "5.1.1",
#             "title": "Introduction to Energy Governance"
#           },
#           {
#             "id": "5.1.2",
#             "title": "Energy Governance Focus Areas"
#           },
#           {
#             "id": "5.1.3",
#             "title": "Cross-Cutting Approaches to Energy Governance"
#           },
#           {
#             "id": "5.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "5.2",
#         "title": "Chapter 2: Policy and Regulatory Frameworks for a Just Energy Transition",
#         "lessons": [
#           {
#             "id": "5.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "5.2.1",
#             "title": "Political Economy and Energy Governance"
#           },
#           {
#             "id": "5.2.2",
#             "title": "Policy Coherence"
#           },
#           {
#             "id": "5.2.3",
#             "title": "Strategic Foresight for Energy Governance"
#           },
#           {
#             "id": "5.2.4",
#             "title": "Adaptive Policies and Regulations"
#           },
#           {
#             "id": "5.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "5.3",
#         "title": "Chapter 3: Inclusive and Effective Institutions",
#         "lessons": [
#           {
#             "id": "5.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "5.3.1",
#             "title": "Integrated Governance for a Just Energy Transition"
#           },
#           {
#             "id": "5.3.2",
#             "title": "Transparency, Public Confidence, and Trust in Institutions"
#           },
#           {
#             "id": "5.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "5.4",
#         "title": "Chapter 4: Civic Engagement and Empowerment",
#         "lessons": [
#           {
#             "id": "5.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "5.4.1",
#             "title": "Civic Engagements And Its Role in Energy Governance"
#           },
#           {
#             "id": "5.4.2",
#             "title": "Facilitating Cooperation with a Heterogeneous Civil Society"
#           },
#           {
#             "id": "5.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "5.5",
#         "title": "Chapter 5: Appropriate and Independent Oversight",
#         "lessons": [
#           {
#             "id": "5.5.0",
#             "title": "Chapter 5 Introduction"
#           },
#           {
#             "id": "5.5.1",
#             "title": "Effective and Independent Oversight"
#           },
#           {
#             "id": "5.5.2",
#             "title": "Agile Oversight"
#           },
#           {
#             "id": "5.5.3",
#             "title": "Gender Lens Oversight and Gender Audits in the Energy Transition"
#           },
#           {
#             "id": "5.5.-1",
#             "title": "Chapter 5 Outro"
#           }
#         ]
#       },
#       {
#         "id": "5.-1",
#         "title": "Module 5 Outro",
#         "lessons": [
#           {
#             "id": "5.-1.0",
#             "title": "Module 5 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "6",
#     "title": "Module 6: The Climate Change-Energy Nexus",
#     "chapters": [
#       {
#         "id": "6.0",
#         "title": "Module 6 Introduction",
#         "lessons": [
#           {
#             "id": "6.0.0",
#             "title": "Module 6 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "6.1",
#         "title": "Chapter 1: Linkages between Energy Systems and Climate Change",
#         "lessons": [
#           {
#             "id": "6.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "6.1.1",
#             "title": "The Impact of Energy Systems on Climate Change"
#           },
#           {
#             "id": "6.1.2",
#             "title": "The Impact of Climate Change on Energy Systems"
#           },
#           {
#             "id": "6.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "6.2",
#         "title": "Chapter 2: Sustainable Energy for Climate Mitigation",
#         "lessons": [
#           {
#             "id": "6.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "6.2.1",
#             "title": "The Climate, Environmental and Health Benefits of Sustainable Energy"
#           },
#           {
#             "id": "6.2.2",
#             "title": "Exploring Renewable Technologies for Climate Mitigation"
#           },
#           {
#             "id": "6.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "6.3",
#         "title": "Chapter 3: Sustainable Energy for Climate Adaptation",
#         "lessons": [
#           {
#             "id": "6.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "6.3.1",
#             "title": "Renewable Energy for Enhancing Climate Resilience"
#           },
#           {
#             "id": "6.3.2",
#             "title": "Enhancing Resilience and Adaptability of Energy Systems"
#           },
#           {
#             "id": "6.3.3",
#             "title": "An Intersectional Approach to Climate Change"
#           },
#           {
#             "id": "6.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "6.4",
#         "title": "Chapter 4: Sustainable Energy Transformation in End-use Sectors",
#         "lessons": [
#           {
#             "id": "6.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "6.4.1",
#             "title": "Decarbonizing the Industry Sector"
#           },
#           {
#             "id": "6.4.2",
#             "title": "Sustainable Buildings: Efficiency, Electrification, and Equity"
#           },
#           {
#             "id": "6.4.3",
#             "title": "Transforming Transport: Electrification and Inclusive Mobility"
#           },
#           {
#             "id": "6.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "6.-1",
#         "title": "Module 6 Outro",
#         "lessons": [
#           {
#             "id": "6.-1.0",
#             "title": "Module 6 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "7",
#     "title": "Module 7: Data in Sustainable Energy",
#     "chapters": [
#       {
#         "id": "7.0",
#         "title": "Module 7 Introduction",
#         "lessons": [
#           {
#             "id": "7.0.0",
#             "title": "Module 7 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "7.1",
#         "title": "Chapter 1: Foundational Concepts of Energy Data and Its Role in Sustainability and Equity",
#         "lessons": [
#           {
#             "id": "7.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "7.1.1",
#             "title": "Introduction to Energy Data"
#           },
#           {
#             "id": "7.1.2",
#             "title": "The Role of Data in Advancing Sustainable Energy And Equity"
#           },
#           {
#             "id": "7.1.3",
#             "title": "The Energy Data Value Chain"
#           },
#           {
#             "id": "7.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "7.2",
#         "title": "Chapter 2: Approaches to Planning, Monitoring, and Evaluation in Sustainable Energy",
#         "lessons": [
#           {
#             "id": "7.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "7.2.1",
#             "title": "Strategic Energy Planning at The Policy Level"
#           },
#           {
#             "id": "7.2.2",
#             "title": "Fundamentals of Project Planning, Monitoring, and Evaluation"
#           },
#           {
#             "id": "7.2.3",
#             "title": "Gender and Intersectionality in Energy Data and Planning"
#           },
#           {
#             "id": "7.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "7.3",
#         "title": "Chapter 3: Tools and Techniques for Data-Driven Insights in Energy",
#         "lessons": [
#           {
#             "id": "7.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "7.3.1",
#             "title": "Data Science Techniques for Energy Analysis"
#           },
#           {
#             "id": "7.3.2",
#             "title": "Energy Modelling Tools and Applications"
#           },
#           {
#             "id": "7.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "7.4",
#         "title": "Chapter 4: Future Directions for Data in the Energy Sector",
#         "lessons": [
#           {
#             "id": "7.4.0",
#             "title": "Chapter 4 Introduction"
#           },
#           {
#             "id": "7.4.1",
#             "title": "A.I. Applications in Energy"
#           },
#           {
#             "id": "7.4.2",
#             "title": "Emerging Trends and Technologies in Energy"
#           },
#           {
#             "id": "7.4.-1",
#             "title": "Chapter 4 Outro"
#           }
#         ]
#       },
#       {
#         "id": "7.-1",
#         "title": "Module 7 Outro",
#         "lessons": [
#           {
#             "id": "7.-1.0",
#             "title": "Module 7 Outro"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "8",
#     "title": "Module 8: Danae",
#     "chapters": [
#       {
#         "id": "8.0",
#         "title": "Module 8 Introduction",
#         "lessons": [
#           {
#             "id": "8.0.0",
#             "title": "Module 8 Introduction"
#           }
#         ]
#       },
#       {
#         "id": "8.1",
#         "title": "Chapter 1: Future Trends and Projections",
#         "lessons": [
#           {
#             "id": "8.1.0",
#             "title": "Chapter 1 Introduction"
#           },
#           {
#             "id": "8.1.1",
#             "title": "Key Drivers of Future Energy Demand and System Transformation"
#           },
#           {
#             "id": "8.1.2",
#             "title": "The Changing Landscape of Energy Supply: Resources, Markets, and Policies"
#           },
#           {
#             "id": "8.1.3",
#             "title": "Challenges, Tipping Points and Solutions in Renewable Energy"
#           },
#           {
#             "id": "8.1.-1",
#             "title": "Chapter 1 Outro"
#           }
#         ]
#       },
#       {
#         "id": "8.2",
#         "title": "Chapter 2: Creating an Enabling Environment for an Innovation-Driven Energy Transition",
#         "lessons": [
#           {
#             "id": "8.2.0",
#             "title": "Chapter 2 Introduction"
#           },
#           {
#             "id": "8.2.1",
#             "title": "Policy and Market Mechanisms for Innovation"
#           },
#           {
#             "id": "8.2.2",
#             "title": "The Role of Emerging Sectors in Future Energy Systems"
#           },
#           {
#             "id": "8.2.3",
#             "title": "Intersectionality as a Framework for Innovation in Energy"
#           },
#           {
#             "id": "8.2.4",
#             "title": "Critical Transformations for the Energy Transition"
#           },
#           {
#             "id": "8.2.-1",
#             "title": "Chapter 2 Outro"
#           }
#         ]
#       },
#       {
#         "id": "8.3",
#         "title": "Chapter 3: Partnerships for Collaboration and Development",
#         "lessons": [
#           {
#             "id": "8.3.0",
#             "title": "Chapter 3 Introduction"
#           },
#           {
#             "id": "8.3.1",
#             "title": "Actionable Steps Toward a Sustainable Energy Future"
#           },
#           {
#             "id": "8.3.2",
#             "title": "Partnership Ecosystems for Sustainable Energy"
#           },
#           {
#             "id": "8.3.3",
#             "title": "Closing key messages and call to action"
#           },
#           {
#             "id": "8.3.-1",
#             "title": "Chapter 3 Outro"
#           }
#         ]
#       },
#       {
#         "id": "8.-1",
#         "title": "Module 8 Outro",
#         "lessons": [
#           {
#             "id": "8.-1.0",
#             "title": "Module 8 Outro"
#           }
#         ]
#       }
#     ]
#   }
# ]
#
# ✅ Module structure saved to: ../04_Outputs/Test/module_structure.json

# %%
import os
import json
import pandas as pd
import re
from uuid import uuid4
from lorem import paragraph, sentence
import random
import copy

# Paths
structure_path = "../04_Outputs/Test/module_structure.json"
toc_path = "../03_Inputs/Test Data/SEA Table of Contents.csv"
schema_dir = "../03_Inputs/Test Data/templates"
output_dir = "../04_Outputs/Test/fake_data"

# Image pool
images = [
    "https://live.staticflickr.com/3775/10838225595_b7d942e452_h.jpg",
    "https://imgs.mongabay.com/wp-content/uploads/sites/20/2025/02/18142934/29572133848_45af12a4bb_k-e1737653671184.jpg",
    "https://live.staticflickr.com/1552/26342931015_38814fbfac_b.jpg",
    "https://www.energy.gov/sites/default/files/styles/full_article_width/public/2023-11/GRIP%20Blog%20Posting%20Clean%20Energy%20Solar%20Panels.jpg?itok=5KDc3kxK",
    "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
    "https://www.healthtechdigital.com/wp-content/uploads/Artificial-Intelligence-in-renewable-energy-market-Study-shows-important-fields-of-application.-min.jpg",
    "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
    "https://live.staticflickr.com/5504/14454539704_b8910261c0_b.jpg",
    "https://www.resusenergy.lk/images/Resus_Enegry_Images/Project_Images/mahiyagnanaya/dji_0008.jpg",
    "https://cdn.prod.website-files.com/6487341142c5367c3cefe169/670703187e5c652197eacf42_Energy.png",
    "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
    "https://web14.bernama.com/storage/photos/830db0b0eb59429f4a6f5618134452c963f433bee8a98",
    "https://iea.imgix.net/5860051d-c92e-4fea-8a90-12bf5334dbef/Renewables_2023_shutterstock_1527609272.jpg",
    "https://www.undp.org/sites/g/files/zskgke326/files/2023-05/1525381088_0.jpg",
    "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
    "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
    "https://elementum-esg.co.uk/wp-content/uploads/2024/04/energy-sources.png"
]

# Load inputs
with open(structure_path) as f:
    module_structure = json.load(f)

toc_df = pd.read_csv(toc_path)
toc_df = toc_df[toc_df["Number"].notna() & toc_df["Lesson Title"].notna()]
toc_lookup = toc_df.set_index("Number")["Overview"].to_dict()

def normalize(text):
    return re.sub(r"[\u202f\xa0]", " ", str(text)).strip()

def load_template(name):
    with open(f"{schema_dir}/{name}", encoding="utf-8") as f:
        return json.load(f)

def save_json(obj, path):
    folder = os.path.dirname(path)
    os.makedirs(folder, exist_ok=True)
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)

def wrap_segments(lesson_id, segments):
    return {"id": lesson_id, "segments": segments}

def overview_text_block(title):
    return {
        "template_id": "text",
        "colorscheme": random.choice(["dark", "light"]),
        "content": {
            "text_elements": [
                {"template_id": "subtitle", "content": {"text": title}},
                {"template_id": "subtitle_small", "content": {"text": sentence().strip(".") + "."}},
                {"template_id": "paragraph_large", "content": {"text": paragraph()}}
            ]
        }
    }

def key_item(template, title, module_num=None, chapter_num=None):
    tmpl = copy.deepcopy(template)
    tmpl["colorscheme"] = random.choice(["dark", "light"])
    content = tmpl["content"]
    content.pop("image", None)
    content.pop("caption", None)
    if "title" in content:
        content["title"] = title

    if "takeaways" in content:
        content["intro"] = sentence()
        content["takeaways"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "title": sentence().split(" ")[0].capitalize() + "...",
            "description": paragraph()
        } for _ in range(3)]

    elif "resources" in content:
        content["intro"] = sentence()
        content["resources"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "text": sentence().split(" ")[0].capitalize() + "...",
            "cta": "Click to download",
            "href":"https://www.undp.org/publications/undps-energy-strategy"
        } for _ in range(3)]

    elif "lessons" in content and module_num and chapter_num:
        progress_states = ["completed", "in_progress", "not_started"]
        content["title"] = "What's next in this chapter?"
        lesson_entries = []
        chapter_prefix = f"{module_num}.{chapter_num}."
        for lesson in flat_items:
            if lesson["id"].startswith(chapter_prefix) and not lesson["id"].endswith(".0") and not lesson["id"].endswith(".-1"):
                lesson_entries.append({
                    "cta": "Go to the lesson",
                    "description": sentence(),
                    "lessonId": lesson["id"],
                    "image": {
                        "src": random.choice(images),
                        "caption": ""
                    },
                    "title": lesson["title"],
                    "type": "Lesson",
                    "progress": random.choice(progress_states)
                })
        content["lessons"] = lesson_entries
        
    elif "objectives" in content:
        content["intro"] = sentence()
        content["objectives"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "title": sentence(),
            "description": paragraph()
        } for _ in range(4)]

    elif "concepts" in content:
        content["concepts"] = [
            {
                "title": sentence(),
                "body": paragraph(),
                "source": "" if i % 8 != 0 else "-International Development Organization"
            } for i in range(5)
        ]

    else:
        content["text"] = paragraph()

    return tmpl

def connection_next_segment(next_lesson):
    segment = copy.deepcopy(templates["connection_next"])
    c = segment.get("content", {})
    c["intro"] = "Next up"
    c["title"] = next_lesson["title"]
    c["cta"] = "Start learning"
    c["nextLessonId"] = next_lesson["id"]
    c["image"] = {"src": random.choice(images), "caption": ""}
    c.pop("caption", None)
    return segment

def make_segment(item, next_item, content_type, module_title):
    module_num, chapter_num, lesson_num = item["id"].split(".")
    full_intro = f"M{module_num}: {module_title} | Chapter {chapter_num} | Lesson {lesson_num}"
    colorscheme = random.choice(["dark", "light"])
    img = random.choice(images)
    segments = []

    if content_type == "module_intro":
        block = copy.deepcopy(templates["module_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["module"] = {"label":"Module","Number":f"{module_num}"}
        block["content"]["title"] = item["title"]
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Module Overview"))
        segments.append(key_item(templates["learning_objectives"], "Learning Objectives"))

    elif content_type == "module_outro":
        segments.append(key_item(templates["module_outro"], "Module Outro"))
        if item["module_id"] != "8":
            segments.append(connection_next_segment(next_item))
        return wrap_segments(item["id"], segments)

    elif content_type == "chapter_intro":
        block = copy.deepcopy(templates["chapter_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["chapter"] = {"label":"Chapter","Number":f"{chapter_num}"}
        block["content"]["title"] = item["title"]
        block["content"]["intro"] = f"M{module_num}: {module_title} | Chapter {chapter_num}"
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Chapter Overview"))
        segments.append(key_item(templates["list_of_lessons"], "What's in this chapter", module_num, chapter_num))

    elif content_type == "chapter_outro":
        segments.append(key_item(templates["chapter_outro"], "Chapter Outro"))

    elif content_type == "lesson":
        block = copy.deepcopy(templates["lesson_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["lesson"] = {"label":"Lesson","Number":f"{lesson_num}"}
        block["content"]["intro"] = full_intro
        block["content"]["title"] = item["title"]
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Lesson Overview"))
        segments.append(key_item(templates["key_concepts"], "Key Concepts"))
        segments.append({
            "template_id": "photo_full_height",
            "colorscheme": colorscheme,
            "content": {
                "image": {"src": img,
                        "caption": ""}
            }
        })
        segments.append({
            "template_id": "text",
            "colorscheme": colorscheme,
            "content": {
                "text_elements": [
                    {"template_id": "subtitle", "content": {"text": sentence().split(".")[0]}},
                    {"template_id": "paragraph_medium", "content": {"text": paragraph()}}
                ]
            }
        })
        segments.append(key_item(templates["key_takeaways"], "Key Takeaways"))
        segments.append(key_item(templates["key_resources"], "Key Resources"))

    if content_type != "module_outro":
        segments.append(connection_next_segment(next_item))

    return wrap_segments(item["id"], segments)

def identify_content_type(lesson_id):
    if lesson_id.endswith(".0.0"): return "module_intro"
    if lesson_id.endswith(".-1.0"): return "module_outro"
    if re.match(r"\d+\.\d+\.0$", lesson_id): return "chapter_intro"
    if re.match(r"\d+\.\d+\.\-1$", lesson_id): return "chapter_outro"
    return "lesson"

# Load templates
templates = {
    "module_cover": load_template("cover/module_cover.json"),
    "chapter_cover": load_template("cover/chapter_cover.json"),
    "lesson_cover": load_template("cover/lesson_cover.json"),
    "learning_objectives": load_template("static/learning_objectives.json"),
    "list_of_lessons": load_template("static/list_of_lessons.json"),
    "key_concepts": load_template("static/key_concepts.json"),
    "key_takeaways": load_template("static/key_takeaways.json"),
    "key_resources": load_template("static/key_resources.json"),
    "chapter_outro": load_template("static/chapter_outro.json"),
    "module_outro": load_template("static/module_outro.json"),
    "connection_next": load_template("connections/connection_next.json")
}

# Flatten structure
flat_items = []
for module in module_structure:
    module_folder = f"{output_dir}/Module {module['id']}"
    for chapter in module["chapters"]:
        for lesson in chapter["lessons"]:
            flat_items.append({
                "module_id": module["id"],
                "title": lesson["title"],
                "id": lesson["id"],
                "folder": module_folder,
                "module_title": module["title"].split(": ")[-1]
            })

# Generate and write content
for idx, item in enumerate(flat_items):
    next_item = flat_items[idx + 1] if idx + 1 < len(flat_items) else {"id": "", "title": ""}
    content_type = identify_content_type(item["id"])
    content = make_segment(item, next_item, content_type, item["module_title"])
    save_json(content, f"{item['folder']}/{item['id']}.json")

print("✅ Fake dataset generation complete.")
# Out:
# ✅ Fake dataset generation complete.
