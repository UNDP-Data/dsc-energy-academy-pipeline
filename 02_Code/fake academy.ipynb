# %%
import os
import json
import pandas as pd
import re
from uuid import uuid4
from lorem import paragraph, sentence
import random
import copy
from pathlib import Path

# %%
# Image pool
images = [
    "https://live.staticflickr.com/3775/10838225595_b7d942e452_h.jpg",
    "https://imgs.mongabay.com/wp-content/uploads/sites/20/2025/02/18142934/29572133848_45af12a4bb_k-e1737653671184.jpg",
    "https://live.staticflickr.com/1552/26342931015_38814fbfac_b.jpg",
    "https://www.energy.gov/sites/default/files/styles/full_article_width/public/2023-11/GRIP%20Blog%20Posting%20Clean%20Energy%20Solar%20Panels.jpg?itok=5KDc3kxK",
    "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
    "https://www.healthtechdigital.com/wp-content/uploads/Artificial-Intelligence-in-renewable-energy-market-Study-shows-important-fields-of-application.-min.jpg",
    "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
    "https://live.staticflickr.com/5504/14454539704_b8910261c0_b.jpg",
    "https://www.resusenergy.lk/images/Resus_Enegry_Images/Project_Images/mahiyagnanaya/dji_0008.jpg",
    "https://cdn.prod.website-files.com/6487341142c5367c3cefe169/670703187e5c652197eacf42_Energy.png",
    "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
    "https://web14.bernama.com/storage/photos/830db0b0eb59429f4a6f5618134452c963f433bee8a98",
    "https://iea.imgix.net/5860051d-c92e-4fea-8a90-12bf5334dbef/Renewables_2023_shutterstock_1527609272.jpg",
    "https://www.undp.org/sites/g/files/zskgke326/files/2023-05/1525381088_0.jpg",
    "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
    "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
    "https://elementum-esg.co.uk/wp-content/uploads/2024/04/energy-sources.png"
]

# %%
# def normalize(text):
#     return re.sub(r"[\u202f\xa0]", " ", str(text)).strip()

# def clean_title(text, prefix=None):
#     text = normalize(text)
#     return re.sub(prefix, "", text).strip() if prefix else text

# def get_titles(df, index_col, title_col):
#     return df[[index_col, title_col]].drop_duplicates().set_index(index_col)[title_col].to_dict()

# def load_and_clean_data(csv_path):
#     df = pd.read_csv(csv_path)
#     df = df[df["Number"].notna() & df["Number"].astype(str).str.match(r"^\d+\.\d+\.\d+$")]
#     df["Module Title"] = df["Module Title"].ffill()
#     df["Chapter Title"] = df["Chapter Title"].ffill()
#     df["Module Number"] = df["Number"].apply(lambda x: str(x).split(".")[0])
#     df["Chapter Number"] = df["Number"].apply(lambda x: ".".join(str(x).split(".")[:2]))
#     return df

# def build_module_structure(df, module_titles, chapter_titles):
#     structure = []
#     for module_num in sorted(module_titles):
#         module_title = clean_title(module_titles[module_num], r"^Module\s*\d+:?\s*")
#         module = {
#             "id": module_num,
#             "title": f"Module {module_num}: {module_title}",
#             "chapters": [
#                 {
#                     "id": f"{module_num}.0",
#                     "title": f"Module {module_num} Introduction",
#                     "lessons": [{
#                         "id": f"{module_num}.0.0",
#                         "title": f"Module {module_num} Introduction"
#                     }]
#                 }
#             ]
#         }

#         chapter_nums = sorted(set(df[df["Module Number"] == module_num]["Chapter Number"]))
#         for chapter_num in chapter_nums:
#             parts = chapter_num.split(".")
#             if len(parts) != 2:
#                 continue
#             chap_short = parts[1]
#             chapter_title = clean_title(chapter_titles.get(chapter_num, f"Chapter {chap_short}"), r"^Chapter\s*\d+:?\s*")

#             lessons = [{
#                 "id": f"{chapter_num}.0",
#                 "title": f"Chapter {chap_short} Introduction"
#             }] + [
#                 {
#                     "id": row["Number"],
#                     "title": clean_title(row["Lesson Title"])
#                 } for _, row in df[df["Chapter Number"] == chapter_num].iterrows()
#             ] + [{
#                 "id": f"{chapter_num}.-1",
#                 "title": f"Chapter {chap_short} Outro"
#             }]

#             module["chapters"].append({
#                 "id": chapter_num,
#                 "title": f"Chapter {chap_short}: {chapter_title}",
#                 "lessons": lessons
#             })

#         module["chapters"].append({
#             "id": f"{module_num}.-1",
#             "title": f"Module {module_num} Outro",
#             "lessons": [{
#                 "id": f"{module_num}.-1.0",
#                 "title": f"Module {module_num} Outro"
#             }]
#         })

#         structure.append(module)
#     return structure

# def save_structure(structure, output_path):
#     with open(output_path, "w", encoding="utf-8") as f:
#         json.dump(structure, f, indent=2, ensure_ascii=False)
#     print(json.dumps(structure, indent=2, ensure_ascii=False))
#     print(f"\n✅ Module structure saved to: {output_path}")

# def generate_structure():
#     csv_path = Path("../03_Inputs/Test Data/SEA Table of Contents.csv")
#     output_path = Path("../04_Outputs/Test/module_structure.json")

#     df = load_and_clean_data(csv_path)
#     module_titles = get_titles(df, "Module Number", "Module Title")
#     chapter_titles = get_titles(df, "Chapter Number", "Chapter Title")
#     structure = build_module_structure(df, module_titles, chapter_titles)
#     save_structure(structure, output_path)

# generate_structure()

# %%
import pandas as pd
import json
import re
from pathlib import Path

def normalize(text):
    return re.sub(r"[\u202f\xa0]", " ", str(text)).strip()

def clean_title(text, prefix=None):
    text = normalize(text)
    return re.sub(prefix, "", text).strip() if prefix else text

def get_titles(df, index_col, title_col):
    return df[[index_col, title_col]].drop_duplicates().set_index(index_col)[title_col].to_dict()

def load_and_clean_data(csv_path):
    df = pd.read_csv(csv_path)
    df = df[df["Number"].notna() & df["Number"].astype(str).str.match(r"^\d+\.\d+\.\d+$")]
    df["Module Title"] = df["Module Title"].ffill()
    df["Chapter Title"] = df["Chapter Title"].ffill()
    df["Module Number"] = df["Number"].apply(lambda x: str(x).split(".")[0])
    df["Chapter Number"] = df["Number"].apply(lambda x: ".".join(str(x).split(".")[:2]))
    return df

def load_metadata(metadata_path):
    metadata = pd.read_csv(metadata_path).fillna("")
    
    # Normalize module/chapter IDs
    metadata["module_id"] = metadata["module_id"].astype(str).str.strip()
    metadata["chapter_id"] = metadata["chapter_id"].astype(str).str.strip()

    # Create metadata dictionaries
    module_meta = metadata[metadata["type"] == "module"].set_index("module_id").to_dict(orient="index")
    chapter_meta = metadata[metadata["type"] == "chapter"].set_index("chapter_id").to_dict(orient="index")
    
    return module_meta, chapter_meta

def build_structure(df, module_titles, chapter_titles, module_meta, chapter_meta):
    modules = []
    for module_num in sorted(module_titles, key=lambda x: int(x)):
        module_id = str(module_num)
        meta = module_meta.get(module_id, {})
        module_title = clean_title(module_titles[module_num], r"^Module\s*\d+:?\s*")

        module = {
            "id": module_id,
            "title": module_title,
            "color": meta.get("color", ""),
            "icon": meta.get("icon", ""),
            "image": {
                "src": meta.get("image_src", ""),
                "caption": meta.get("image_caption", "")
            },
            "description": meta.get("description", ""),
            "percentComplete": meta.get("percentComplete", ""),
            "estimatedTime": meta.get("estimatedTime", ""),
            "chapters": []
        }

        chapter_nums = sorted(set(df[df["Module Number"] == module_num]["Chapter Number"]))
        for j, chapter_num in enumerate(chapter_nums):
            chapter_id = str(chapter_num)
            chapter_title_raw = chapter_titles.get(chapter_num, f"Chapter {j+1}")
            chapter_title = clean_title(chapter_title_raw, r"^Chapter\s*\d+:?\s*")
            cmeta = chapter_meta.get(chapter_id, {})

            lessons = []
            chapter_df = df[df["Chapter Number"] == chapter_num]
            for k, (_, row) in enumerate(chapter_df.iterrows()):
                lesson_id = row["Number"]
                lesson_title = clean_title(row["Lesson Title"])
                lessons.append({
                    "type": ["lesson", "lesson", "quiz", "takeaways", "certification"][k % 5],
                    "title": f"Lesson {lesson_id} <strong>{lesson_title}</strong>",
                    "id": lesson_id,
                    "progress": ["completed", "completed", "in_progress", "in_progress", "not_started"][k % 5]
                })

            chapter = {
                "id": chapter_id,
                "title": f"Chapter {j+1}: <strong>{chapter_title}</strong>",
                "icon": cmeta.get("icon", ""),
                "image": {
                    "src": cmeta.get("image_src", ""),
                    "caption": cmeta.get("image_caption", "")
                },
                "description": cmeta.get("description", ""),
                "lessons": lessons
            }

            module["chapters"].append(chapter)

        modules.append(module)
    return {"modules": modules}

def save_structure(structure, output_path):
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(structure, f, indent=2, ensure_ascii=False)
    print(json.dumps(structure, indent=2, ensure_ascii=False))
    print(f"\n✅ Module structure saved to: {output_path}")

def generate_structure():
    toc_csv_path = Path("../03_Inputs/Test Data/SEA Table of Contents.csv")
    metadata_path = Path("../03_Inputs/Test Data/Module-Chapter-Details.csv")
    output_path = Path("../04_Outputs/Test/module_structure.json")

    df = load_and_clean_data(toc_csv_path)
    module_titles = get_titles(df, "Module Number", "Module Title")
    chapter_titles = get_titles(df, "Chapter Number", "Chapter Title")
    module_meta, chapter_meta = load_metadata(metadata_path)
    structure = build_structure(df, module_titles, chapter_titles, module_meta, chapter_meta)
    save_structure(structure, output_path)

generate_structure()
# Out:
# {
#   "modules": [
#     {
#       "id": "1",
#       "title": "Intro to Sustainable Energy for Development",
#       "color": "#00C1FF",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 100.0,
#       "estimatedTime": "45 min",
#       "chapters": [
#         {
#           "id": "1.1",
#           "title": "Chapter 1: <strong>Introduction to Energy Systems</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://live.staticflickr.com/3775/10838225595_b7d942e452_h.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 1.1.1 <strong>Introduction to the Energy for Development pathway</strong>",
#               "id": "1.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 1.1.2 <strong>The Sustainable Energy Landscape</strong>",
#               "id": "1.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 1.1.3 <strong>The Path to Achieving Universal Energy Access by 2030</strong>",
#               "id": "1.1.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 1.1.4 <strong>Financing the Sustainable Energy Revolution</strong>",
#               "id": "1.1.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "1.2",
#           "title": "Chapter 2: <strong>Approaches, Methods and Tools for Strategic Innovation</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 1.2.1 <strong>Access to electricity and clean cooking (SDG 7.1)</strong>",
#               "id": "1.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 1.2.2 <strong>Renewable energy (SDG 7.2)</strong>",
#               "id": "1.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 1.2.3 <strong>Energy Efficiency (SDG 7.3)</strong>",
#               "id": "1.2.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 1.2.4 <strong>Integrated Approach</strong>",
#               "id": "1.2.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "1.3",
#           "title": "Chapter 3: <strong>Regional Perspective</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 1.3.1 <strong>Latin America and the Caribbean</strong>",
#               "id": "1.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 1.3.2 <strong>Eastern Europe and Central Asia</strong>",
#               "id": "1.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 1.3.3 <strong>Arab States</strong>",
#               "id": "1.3.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 1.3.4 <strong>Asia-Pacific</strong>",
#               "id": "1.3.4",
#               "progress": "in_progress"
#             },
#             {
#               "type": "certification",
#               "title": "Lesson 1.3.5 <strong>Africa</strong>",
#               "id": "1.3.5",
#               "progress": "not_started"
#             }
#           ]
#         },
#         {
#           "id": "1.4",
#           "title": "Chapter 4: <strong>The Sustainable Energy Academy</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://live.staticflickr.com/5504/14454539704_b8910261c0_b.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 1.4.1 <strong>The Sustainable Energy Academy: Modules 2-8</strong>",
#               "id": "1.4.1",
#               "progress": "completed"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "2",
#       "title": "Energy Access and Inclusive Energy Services",
#       "color": "#1F8C3E",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 75.0,
#       "estimatedTime": "51 min",
#       "chapters": [
#         {
#           "id": "2.1",
#           "title": "Chapter 1: <strong>Topic Overview and Background</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 2.1.1 <strong>Energy Access - Core Concepts</strong>",
#               "id": "2.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 2.1.2 <strong>Sustainable Energy to power development</strong>",
#               "id": "2.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 2.1.3 <strong>Energy Poverty and Fuel Poverty</strong>",
#               "id": "2.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "2.2",
#           "title": "Chapter 2: <strong>Current Status, Trends and Barriers to Energy Access</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://elementum-esg.co.uk/wp-content/uploads/2024/04/energy-sources.png",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 2.2.1 <strong>The Energy Access Landscape</strong>",
#               "id": "2.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 2.2.2 <strong>Status and Trends</strong>",
#               "id": "2.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 2.2.3 <strong>Challenges for universal energy access</strong>",
#               "id": "2.2.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "2.3",
#           "title": "Chapter 3: <strong>Bridging the Energy Access Gap</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 2.3.1 <strong>An Intersectional Approach</strong>",
#               "id": "2.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 2.3.2 <strong>Technological Solutions</strong>",
#               "id": "2.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 2.3.3 <strong>Financing Mechanisms</strong>",
#               "id": "2.3.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 2.3.4 <strong>Policy Frameworks</strong>",
#               "id": "2.3.4",
#               "progress": "in_progress"
#             },
#             {
#               "type": "certification",
#               "title": "Lesson 2.3.5 <strong>Collaborative Multi-Stakeholder Partnerships</strong>",
#               "id": "2.3.5",
#               "progress": "not_started"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "3",
#       "title": "Just Energy Transition",
#       "color": "#FF9F1C",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 50.0,
#       "estimatedTime": "57 min",
#       "chapters": [
#         {
#           "id": "3.1",
#           "title": "Chapter 1: <strong>Introduction to the Energy Transition Landscape</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://elementum-esg.co.uk/wp-content/uploads/2024/04/energy-sources.png",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 3.1.1 <strong>The Energy Transition In Context</strong>",
#               "id": "3.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 3.1.2 <strong>Unpacking The Concept Of A Just Energy Transition</strong>",
#               "id": "3.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 3.1.3 <strong>Key Challenges In The Global South</strong>",
#               "id": "3.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "3.2",
#           "title": "Chapter 2: <strong>Ensuring a Just Transition for Workers and Affected Communities</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 3.2.1 <strong>Human rights and socio-economic impacts</strong>",
#               "id": "3.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 3.2.2 <strong>Worker Retraining and Employment Disparities</strong>",
#               "id": "3.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 3.2.3 <strong>Social Safety Nets and Income Support</strong>",
#               "id": "3.2.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 3.2.4 <strong>Community-led sustainable energy projects and community-based solutions</strong>",
#               "id": "3.2.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "3.3",
#           "title": "Chapter 3: <strong>A JET that Preserves Nature and Catalyzes Economic Growth</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.energy.gov/sites/default/files/styles/full_article_width/public/2023-11/GRIP%20Blog%20Posting%20Clean%20Energy%20Solar%20Panels.jpg?itok=5KDc3kxK",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 3.3.1 <strong>Critical Minerals and Materials</strong>",
#               "id": "3.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 3.3.2 <strong>Environmental Concerns of Clean Energy Technology Deployment</strong>",
#               "id": "3.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 3.3.3 <strong>Advancing the Value Chain</strong>",
#               "id": "3.3.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "3.4",
#           "title": "Chapter 4: <strong>Strategic Governance and Partnership Models for Just Energy Transitions</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://cdn.prod.website-files.com/6487341142c5367c3cefe169/670703187e5c652197eacf42_Energy.png",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 3.4.1 <strong>Governance Strategies for a Just Energy Transition</strong>",
#               "id": "3.4.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 3.4.2 <strong>Importance of Proactive Planning and Strategic Foresight</strong>",
#               "id": "3.4.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 3.4.3 <strong>Just Energy Transition Partnerships (JET-P)</strong>",
#               "id": "3.4.3",
#               "progress": "in_progress"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "4",
#       "title": "Sustainable Energy Finance",
#       "color": "#6A4C93",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://live.staticflickr.com/3775/10838225595_b7d942e452_h.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 25.0,
#       "estimatedTime": "63 min",
#       "chapters": [
#         {
#           "id": "4.1",
#           "title": "Chapter 1: <strong>Introduction to Sustainable Energy Finance and Market Dynamics</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://iea.imgix.net/5860051d-c92e-4fea-8a90-12bf5334dbef/Renewables_2023_shutterstock_1527609272.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 4.1.1 <strong>Fundamentals of Sustainable Energy Financing</strong>",
#               "id": "4.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 4.1.2 <strong>The Global Energy Investment Landscape of Energy Investments</strong>",
#               "id": "4.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 4.1.3 <strong>An Overview of Sustainable Energy Market Dynamics</strong>",
#               "id": "4.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "4.2",
#           "title": "Chapter 2: <strong>Public Sector and Sustainable Energy Finance</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2023-05/1525381088_0.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 4.2.1 <strong>Role of Public Sector in Sustainable Energy Finance</strong>",
#               "id": "4.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 4.2.2 <strong>Financial Health Policies and Regulation</strong>",
#               "id": "4.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 4.2.3 <strong>The Energy Subsidy Reform</strong>",
#               "id": "4.2.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "4.3",
#           "title": "Chapter 3: <strong>Scaling Up Private Sector Investment in Sustainable Energy</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2023-05/1525381088_0.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 4.3.1 <strong>Private Sector Investment in Sustainable Energy</strong>",
#               "id": "4.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 4.3.2 <strong>Risk Mitigation Strategies</strong>",
#               "id": "4.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 4.3.3 <strong>Blended Finance</strong>",
#               "id": "4.3.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "4.4",
#           "title": "Chapter 4: <strong>Innovative Financial Instruments and Tools for Renewable Energy</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 4.4.1 <strong>Thematic Bonds (Public and Corporate)</strong>",
#               "id": "4.4.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 4.4.2 <strong>Debt Swaps (Debt for Energy, D4E)</strong>",
#               "id": "4.4.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 4.4.3 <strong>Carbon Financing</strong>",
#               "id": "4.4.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 4.4.4 <strong>Emerging Technologies: AI-Powered and Digital Financing Solutions</strong>",
#               "id": "4.4.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "4.5",
#           "title": "Chapter 5: <strong>Cross-Sectional Issues in Sustainable Energy Finance</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.resusenergy.lk/images/Resus_Enegry_Images/Project_Images/mahiyagnanaya/dji_0008.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 4.5.1 <strong>Partnerships for Sustainable Energy Investments</strong>",
#               "id": "4.5.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 4.5.2 <strong>Gender Equality And Sustainable Energy Finance</strong>",
#               "id": "4.5.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 4.5.3 <strong>Regional Priorities</strong>",
#               "id": "4.5.3",
#               "progress": "in_progress"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "5",
#       "title": "Energy Governance for a Just Energy Transition",
#       "color": "#00C1FF",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://live.staticflickr.com/1552/26342931015_38814fbfac_b.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 100.0,
#       "estimatedTime": "69 min",
#       "chapters": [
#         {
#           "id": "5.1",
#           "title": "Chapter 1: <strong>An Overview of Energy Governance</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://web14.bernama.com/storage/photos/830db0b0eb59429f4a6f5618134452c963f433bee8a98",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 5.1.1 <strong>Introduction to Energy Governance</strong>",
#               "id": "5.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 5.1.2 <strong>Energy Governance Focus Areas</strong>",
#               "id": "5.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 5.1.3 <strong>Cross-Cutting Approaches to Energy Governance</strong>",
#               "id": "5.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "5.2",
#           "title": "Chapter 2: <strong>Policy and Regulatory Frameworks for a Just Energy Transition</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 5.2.1 <strong>Political Economy and Energy Governance</strong>",
#               "id": "5.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 5.2.2 <strong>Policy Coherence</strong>",
#               "id": "5.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 5.2.3 <strong>Strategic Foresight for Energy Governance</strong>",
#               "id": "5.2.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 5.2.4 <strong>Adaptive Policies and Regulations</strong>",
#               "id": "5.2.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "5.3",
#           "title": "Chapter 3: <strong>Inclusive and Effective Institutions</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2023-05/1525381088_0.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 5.3.1 <strong>Integrated Governance for a Just Energy Transition</strong>",
#               "id": "5.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 5.3.2 <strong>Transparency, Public Confidence, and Trust in Institutions</strong>",
#               "id": "5.3.2",
#               "progress": "completed"
#             }
#           ]
#         },
#         {
#           "id": "5.4",
#           "title": "Chapter 4: <strong>Civic Engagement and Empowerment</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 5.4.1 <strong>Civic Engagements And Its Role in Energy Governance</strong>",
#               "id": "5.4.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 5.4.2 <strong>Facilitating Cooperation with a Heterogeneous Civil Society</strong>",
#               "id": "5.4.2",
#               "progress": "completed"
#             }
#           ]
#         },
#         {
#           "id": "5.5",
#           "title": "Chapter 5: <strong>Appropriate and Independent Oversight</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://elements-resized.envatousercontent.com/elements-video-cover-images/3254f24d-2426-43ae-b55d-aedc5cd25fea/video_preview/video_preview_0000.jpg?w=1400&cf_fit=cover&q=85&format=auto&s=8801a0bc8becf7ebb4baee10701611ef4b9f3f6939ca660e3a0b90514b7cf8d2",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 5.5.1 <strong>Effective and Independent Oversight</strong>",
#               "id": "5.5.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 5.5.2 <strong>Agile Oversight</strong>",
#               "id": "5.5.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 5.5.3 <strong>Gender Lens Oversight and Gender Audits in the Energy Transition</strong>",
#               "id": "5.5.3",
#               "progress": "in_progress"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "6",
#       "title": "The Climate Change-Energy Nexus",
#       "color": "#1F8C3E",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 75.0,
#       "estimatedTime": "75 min",
#       "chapters": [
#         {
#           "id": "6.1",
#           "title": "Chapter 1: <strong>Linkages between Energy Systems and Climate Change</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 6.1.1 <strong>The Impact of Energy Systems on Climate Change</strong>",
#               "id": "6.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 6.1.2 <strong>The Impact of Climate Change on Energy Systems</strong>",
#               "id": "6.1.2",
#               "progress": "completed"
#             }
#           ]
#         },
#         {
#           "id": "6.2",
#           "title": "Chapter 2: <strong>Sustainable Energy for Climate Mitigation</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 6.2.1 <strong>The Climate, Environmental and Health Benefits of Sustainable Energy</strong>",
#               "id": "6.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 6.2.2 <strong>Exploring Renewable Technologies for Climate Mitigation</strong>",
#               "id": "6.2.2",
#               "progress": "completed"
#             }
#           ]
#         },
#         {
#           "id": "6.3",
#           "title": "Chapter 3: <strong>Sustainable Energy for Climate Adaptation</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 6.3.1 <strong>Renewable Energy for Enhancing Climate Resilience</strong>",
#               "id": "6.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 6.3.2 <strong>Enhancing Resilience and Adaptability of Energy Systems</strong>",
#               "id": "6.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 6.3.3 <strong>An Intersectional Approach to Climate Change</strong>",
#               "id": "6.3.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "6.4",
#           "title": "Chapter 4: <strong>Sustainable Energy Transformation in End-use Sectors</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.powerengineeringint.com/wp-content/uploads/2024/04/renewable-energy_cybersecurity.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 6.4.1 <strong>Decarbonizing the Industry Sector</strong>",
#               "id": "6.4.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 6.4.2 <strong>Sustainable Buildings: Efficiency, Electrification, and Equity</strong>",
#               "id": "6.4.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 6.4.3 <strong>Transforming Transport: Electrification and Inclusive Mobility</strong>",
#               "id": "6.4.3",
#               "progress": "in_progress"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "7",
#       "title": "Data in Sustainable Energy",
#       "color": "#FF9F1C",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://imgs.mongabay.com/wp-content/uploads/sites/20/2025/02/18142934/29572133848_45af12a4bb_k-e1737653671184.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 50.0,
#       "estimatedTime": "81 min",
#       "chapters": [
#         {
#           "id": "7.1",
#           "title": "Chapter 1: <strong>Foundational Concepts of Energy Data and Its Role in Sustainability and Equity</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.healthtechdigital.com/wp-content/uploads/Artificial-Intelligence-in-renewable-energy-market-Study-shows-important-fields-of-application.-min.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 7.1.1 <strong>Introduction to Energy Data</strong>",
#               "id": "7.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 7.1.2 <strong>The Role of Data in Advancing Sustainable Energy And Equity</strong>",
#               "id": "7.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 7.1.3 <strong>The Energy Data Value Chain</strong>",
#               "id": "7.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "7.2",
#           "title": "Chapter 2: <strong>Approaches to Planning, Monitoring, and Evaluation in Sustainable Energy</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://live.staticflickr.com/1552/26342931015_38814fbfac_b.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 7.2.1 <strong>Strategic Energy Planning at The Policy Level</strong>",
#               "id": "7.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 7.2.2 <strong>Fundamentals of Project Planning, Monitoring, and Evaluation</strong>",
#               "id": "7.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 7.2.3 <strong>Gender and Intersectionality in Energy Data and Planning</strong>",
#               "id": "7.2.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "7.3",
#           "title": "Chapter 3: <strong>Tools and Techniques for Data-Driven Insights in Energy</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 7.3.1 <strong>Data Science Techniques for Energy Analysis</strong>",
#               "id": "7.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 7.3.2 <strong>Energy Modelling Tools and Applications</strong>",
#               "id": "7.3.2",
#               "progress": "completed"
#             }
#           ]
#         },
#         {
#           "id": "7.4",
#           "title": "Chapter 4: <strong>Future Directions for Data in the Energy Sector</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://csis-website-prod.s3.amazonaws.com/s3fs-public/2024-01/AdobeStock_40869586_Crop1.jpg?VersionId=1HVO4O4gG312NydD1v8CElYVGjfLOYtH",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 7.4.1 <strong>A.I. Applications in Energy</strong>",
#               "id": "7.4.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 7.4.2 <strong>Emerging Trends and Technologies in Energy</strong>",
#               "id": "7.4.2",
#               "progress": "completed"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "8",
#       "title": "Danae",
#       "color": "#6A4C93",
#       "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#       "image": {
#         "src": "https://iea.imgix.net/5860051d-c92e-4fea-8a90-12bf5334dbef/Renewables_2023_shutterstock_1527609272.jpg",
#         "caption": ""
#       },
#       "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#       "percentComplete": 25.0,
#       "estimatedTime": "87 min",
#       "chapters": [
#         {
#           "id": "8.1",
#           "title": "Chapter 1: <strong>Future Trends and Projections</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://live.staticflickr.com/1552/26342931015_38814fbfac_b.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 8.1.1 <strong>Key Drivers of Future Energy Demand and System Transformation</strong>",
#               "id": "8.1.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 8.1.2 <strong>The Changing Landscape of Energy Supply: Resources, Markets, and Policies</strong>",
#               "id": "8.1.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 8.1.3 <strong>Challenges, Tipping Points and Solutions in Renewable Energy</strong>",
#               "id": "8.1.3",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "8.2",
#           "title": "Chapter 2: <strong>Creating an Enabling Environment for an Innovation-Driven Energy Transition</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://www.undp.org/sites/g/files/zskgke326/files/2022-07/UNDP-Peru-2018_rural_solar_04-Photo%20UNDP%20Peru-Monica%20Sua%CC%81rez%20Galindo.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 8.2.1 <strong>Policy and Market Mechanisms for Innovation</strong>",
#               "id": "8.2.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 8.2.2 <strong>The Role of Emerging Sectors in Future Energy Systems</strong>",
#               "id": "8.2.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 8.2.3 <strong>Intersectionality as a Framework for Innovation in Energy</strong>",
#               "id": "8.2.3",
#               "progress": "in_progress"
#             },
#             {
#               "type": "takeaways",
#               "title": "Lesson 8.2.4 <strong>Critical Transformations for the Energy Transition</strong>",
#               "id": "8.2.4",
#               "progress": "in_progress"
#             }
#           ]
#         },
#         {
#           "id": "8.3",
#           "title": "Chapter 3: <strong>Partnerships for Collaboration and Development</strong>",
#           "icon": "https://www.svgrepo.com/show/33586/renewable-energy.svg",
#           "image": {
#             "src": "https://coolermed.com/wp-content/uploads/2023/02/what-is-sustainable-energy-how-to-apply-it-to-medical-use.jpg",
#             "caption": ""
#           },
#           "description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nullam malesuada fringilla venenatis. Duis massa felis, maximus vel arcu in, tempor tempus enim. Etiam volutpat mattis turpis, in posuere dolor iaculis vitae.",
#           "lessons": [
#             {
#               "type": "lesson",
#               "title": "Lesson 8.3.1 <strong>Actionable Steps Toward a Sustainable Energy Future</strong>",
#               "id": "8.3.1",
#               "progress": "completed"
#             },
#             {
#               "type": "lesson",
#               "title": "Lesson 8.3.2 <strong>Partnership Ecosystems for Sustainable Energy</strong>",
#               "id": "8.3.2",
#               "progress": "completed"
#             },
#             {
#               "type": "quiz",
#               "title": "Lesson 8.3.3 <strong>Closing key messages and call to action</strong>",
#               "id": "8.3.3",
#               "progress": "in_progress"
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
#
# ✅ Module structure saved to: ../04_Outputs/Test/module_structure.json

# %%
# Paths
structure_path = "../04_Outputs/Test/module_structure.json"
toc_path = "../03_Inputs/Test Data/SEA Table of Contents.csv"
schema_dir = "../03_Inputs/Test Data/templates"
output_dir = "../04_Outputs/Test/fake_data"


# Load inputs
with open(structure_path) as f:
    module_structure = json.load(f)

toc_df = pd.read_csv(toc_path)
toc_df = toc_df[toc_df["Number"].notna() & toc_df["Lesson Title"].notna()]
toc_lookup = toc_df.set_index("Number")["Overview"].to_dict()

def normalize(text):
    return re.sub(r"[\u202f\xa0]", " ", str(text)).strip()

def load_template(name):
    with open(f"{schema_dir}/{name}", encoding="utf-8") as f:
        return json.load(f)

def save_json(obj, path):
    folder = os.path.dirname(path)
    os.makedirs(folder, exist_ok=True)
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)

def wrap_segments(lesson_id, segments):
    return {"id": lesson_id, "segments": segments}

def overview_text_block(title):
    return {
        "template_id": "text",
        "colorscheme": random.choice(["dark", "light"]),
        "content": {
            "text_elements": [
                {"template_id": "subtitle", "content": {"text": title}},
                {"template_id": "subtitle_small", "content": {"text": sentence().strip(".") + "."}},
                {"template_id": "paragraph_large", "content": {"text": paragraph()}}
            ]
        }
    }

def key_item(template, title, module_num=None, chapter_num=None):
    tmpl = copy.deepcopy(template)
    tmpl["colorscheme"] = random.choice(["dark", "light"])
    content = tmpl["content"]
    content.pop("image", None)
    content.pop("caption", None)
    if "title" in content:
        content["title"] = title

    if "takeaways" in content:
        content["intro"] = sentence()
        content["takeaways"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "title": sentence().split(" ")[0].capitalize() + "...",
            "description": paragraph()
        } for _ in range(3)]

    elif "resources" in content:
        content["intro"] = sentence()
        content["resources"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "text": sentence().split(" ")[0].capitalize() + "...",
            "cta": "Click to download",
            "href":"https://www.undp.org/publications/undps-energy-strategy"
        } for _ in range(3)]

    elif "lessons" in content and module_num and chapter_num:
        progress_states = ["completed", "in_progress", "not_started"]
        content["title"] = "What's next in this chapter?"
        lesson_entries = []
        chapter_prefix = f"{module_num}.{chapter_num}."
        for lesson in flat_items:
            if lesson["id"].startswith(chapter_prefix) and not lesson["id"].endswith(".0") and not lesson["id"].endswith(".-1"):
                lesson_entries.append({
                    "cta": "Go to the lesson",
                    "description": sentence(),
                    "lessonId": lesson["id"],
                    "image": {
                        "src": random.choice(images),
                        "caption": ""
                    },
                    "title": lesson["title"],
                    "type": "Lesson",
                    "progress": random.choice(progress_states)
                })
        content["lessons"] = lesson_entries
        
    elif "objectives" in content:
        content["intro"] = sentence()
        content["objectives"] = [{
            "image": {"src": random.choice(images),
                        "caption": ""},
            "title": sentence(),
            "description": paragraph()[:200]
        } for _ in range(6)]

    elif "concepts" in content:
        content["concepts"] = [
            {
                "title": sentence()[:20],
                "body": paragraph()[:250],
                "source": "" if i % 8 != 0 else "-International Development Organization"
            } for i in range(3)
        ]

    else:
        content["text"] = paragraph()

    return tmpl

def connection_next_segment(next_lesson):
    segment = copy.deepcopy(templates["connection_next"])
    c = segment.get("content", {})
    c["intro"] = "Next up"
    c["title"] = next_lesson["title"]
    c["cta"] = "Start learning"
    c["nextLessonId"] = next_lesson["id"]
    c["image"] = {"src": random.choice(images), "caption": ""}
    c.pop("caption", None)
    return segment

def make_segment(item, next_item, content_type, module_title):
    module_num, chapter_num, lesson_num = item["id"].split(".")
    full_intro = f"M{module_num}: {module_title} | Chapter {chapter_num} | Lesson {lesson_num}"
    colorscheme = random.choice(["dark", "light"])
    img = random.choice(images)
    segments = []

    if content_type == "module_intro":
        block = copy.deepcopy(templates["module_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["module"] = {"label":"Module","Number":f"{module_num}"}
        block["content"]["title"] = item["title"]
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Module Overview"))
        segments.append(key_item(templates["learning_objectives"], "Learning Objectives"))

    elif content_type == "module_outro":
        block = copy.deepcopy(templates["module_outro"])
        block["colorscheme"] = colorscheme
        block["content"]["title"] = item["title"]
        block["content"]["nextBlock"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        if item["module_id"] != "8":
            segments.append(connection_next_segment(next_item))
        return wrap_segments(item["id"], segments)

    elif content_type == "chapter_intro":
        block = copy.deepcopy(templates["chapter_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["chapter"] = {"label":"Chapter","Number":f"{chapter_num}"}
        block["content"]["title"] = item["title"]
        block["content"]["subtitle"] = f"M{module_num}: {module_title} | Chapter {chapter_num}"
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Chapter Overview"))
        segments.append(key_item(templates["list_of_lessons"], "What's in this chapter", module_num, chapter_num))

    elif content_type == "chapter_outro":
        block = copy.deepcopy(templates["chapter_outro"])
        block["colorscheme"] = colorscheme
        block["content"]["subtitle"] = item["title"]
        block["content"]["title"] = f"M{module_num} | Chapter {chapter_num}"
        block["content"]["nextBlock"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
    elif content_type == "lesson":
        block = copy.deepcopy(templates["lesson_cover"])
        block["colorscheme"] = colorscheme
        block["content"]["lesson"] = {"label":"Lesson","Number":f"{lesson_num}"}
        block["content"]["intro"] = full_intro
        block["content"]["title"] = item["title"]
        block["content"]["image"] = {"src": img,
                        "caption": ""}
        segments.append(block)
        segments.append(overview_text_block("Lesson Overview"))
        segments.append(key_item(templates["key_concepts"], "Key Concepts"))
        segments.append({
            "template_id": "photo_full_height",
            "colorscheme": colorscheme,
            "content": {
                "image": {"src": img,
                        "caption": ""}
            }
        })
        segments.append({
            "template_id": "text",
            "colorscheme": colorscheme,
            "content": {
                "text_elements": [
                    {"template_id": "subtitle", "content": {"text": sentence().split(".")[0]}},
                    {"template_id": "paragraph_medium", "content": {"text": paragraph()}}
                ]
            }
        })
        segments.append(key_item(templates["key_takeaways"], "Key Takeaways"))
        segments.append(key_item(templates["key_resources"], "Key Resources"))

    if content_type != "module_outro":
        segments.append(connection_next_segment(next_item))

    return wrap_segments(item["id"], segments)

def identify_content_type(lesson_id):
    if lesson_id.endswith(".0.0"): return "module_intro"
    if lesson_id.endswith(".-1.0"): return "module_outro"
    if re.match(r"\d+\.\d+\.0$", lesson_id): return "chapter_intro"
    if re.match(r"\d+\.\d+\.\-1$", lesson_id): return "chapter_outro"
    return "lesson"

# Load templates
templates = {
    "module_cover": load_template("cover/module_cover.json"),
    "chapter_cover": load_template("cover/chapter_cover.json"),
    "lesson_cover": load_template("cover/lesson_cover.json"),
    "learning_objectives": load_template("static/learning_objectives.json"),
    "list_of_lessons": load_template("static/list_of_lessons.json"),
    "key_concepts": load_template("static/key_concepts.json"),
    "key_takeaways": load_template("static/key_takeaways.json"),
    "key_resources": load_template("static/key_resources.json"),
    "chapter_outro": load_template("static/chapter_outro.json"),
    "module_outro": load_template("static/module_outro.json"),
    "connection_next": load_template("connections/connection_next.json")
}

# Flatten structure
flat_items = []
for module in module_structure:
    module_folder = f"{output_dir}/Module {module['id']}"
    for chapter in module["chapters"]:
        for lesson in chapter["lessons"]:
            flat_items.append({
                "module_id": module["id"],
                "title": lesson["title"],
                "id": lesson["id"],
                "folder": module_folder,
                "module_title": module["title"].split(": ")[-1]
            })

# Generate and write content
for idx, item in enumerate(flat_items):
    next_item = flat_items[idx + 1] if idx + 1 < len(flat_items) else {"id": "", "title": ""}
    content_type = identify_content_type(item["id"])
    content = make_segment(item, next_item, content_type, item["module_title"])
    save_json(content, f"{item['folder']}/{item['id']}.json")

print("✅ Fake dataset generation complete.")
# Out:
# ✅ Fake dataset generation complete.
