# %% [markdown]
# # Academy data pipeline -- Data extraction from text to CSV
#
# <h3>Extracting data from modules text and save it in a dataframe: Approach </h3>
# <ol type="1">
#   <li> Reading the Document and split it into parts ( sections, slides, texts, diagrams/photos) </li>
#     <li> Structure the Data: Parsing the data following the hierarchical structure of the doc  </li>
#     <li> Create DataFrame:Convert this structured data into a pandas DataFrame </li>
#
# </ol>

# %%
# Import libraries 
from docx import Document 
import pandas as pd
import os
import re

# %% [markdown]
# Read the doc

# %%
# read the test .docx file
docx_path = 'Modules/sea-test.docx'

# load the document
document = Document(docx_path)

# extract text from the document
doc_text = []
for para in document.paragraphs:
    doc_text.append(para.text)

# print the text
print('\n'.join(doc_text))
# Out:
# #5.3.2 Energy Transition
#
# *Slide* [Innovation in the Just Energy Transition]
#
# **Photo**
# img=access-1
#
# **Text-narrow**
#
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc Energy lorem ipsum alo vil cu li li oppo energy sustainable etc Energy lorem ipsum alo vil cu li li oppo energy sustainable
#
#
# **Text-wide**
# Energy lorem ipsum alo vil cu li li oppo
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc
#
# *Slide* [Energy Access]
#
# **Photo-Box**
#
# img=access-3
#
# **Text**
#
# Energy lorem ipsum alo vil
#
# **Diagram**
#
# dgm=transition-2
#
# Here the diagram shows that renewable energy is good.
#
#
# **Text-dark-6**
#
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc
#
#
# **Text-dark-4**
#
# Energy lorem ipsum alo vil cu li li oppo energy sustainable etc Energy lorem ipsum alo vil cu li li oppo energy sustainable etc Energy lorem ipsum alo vil cu li li oppo energy sustainable
#
#
# **Photo-5**
#
# img=access-1
#
# **Photo-5**
#
# img=access-1
#
#
# *****

# %% [markdown]
# Structure the data

# %%
def parse_docx(doc_path):
    doc = Document(doc_path)
    data = []
    current_section = None
    section_title = None
    slide_count = 0
    current_slide = None
    slide_title = None

    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue

        if text.startswith('#'):
            # Section header
            current_section = text[1:].split()[0]  # Full section number e.g., 5.3.2
            section_title = ' '.join(text[1:].split()[1:])
            data.append({
                "Type": "Text",
                "Code": "",
                "Section Number": current_section,
                "Section Title": section_title,
                "Slide Number": "",
                "Slide Title": "",
                "Text": section_title,
                "Order": len(data) + 1
            })
        elif '*Slide*' in text:
            # Slide header
            slide_count += 1
            current_slide = slide_count
            slide_title = text.split('[', 1)[1].split(']')[0]
            data.append({
                "Type": "Text",
                "Code": "",
                "Section Number": current_section,
                "Section Title": section_title,
                "Slide Number": current_slide,
                "Slide Title": slide_title,
                "Text": slide_title,
                "Order": len(data) + 1
            })
        else:
            # Identify type of content and handle image codes
            text_type = "Text"
            code = ""
            content = text
            if '**' in text:
                text_type = text.split('**')[1]
                content = para.text.split('\n\n', 1)[1].strip() if '\n\n' in para.text else text
                if 'img=' in content or 'dgm=' in content:
                    code = content.split('\n')[0].split('=')[1].strip()
                    content = '\n'.join(content.split('\n')[1:])
            
            data.append({
                "Type": text_type,
                "Code": code,
                "Section Number": current_section,
                "Section Title": section_title,
                "Slide Number": current_slide,
                "Slide Title": slide_title,
                "Text": content,
                "Order": len(data) + 1
            })

    return pd.DataFrame(data)

# Path to your .docx file
df = parse_docx(docx_path)
df
# Out:
#            Type Code Section Number      Section Title Slide Number  \
# 0          Text               5.3.2  Energy Transition
# 1          Text               5.3.2  Energy Transition            1
# 2         Photo               5.3.2  Energy Transition            1
# 3          Text               5.3.2  Energy Transition            1
# 4   Text-narrow               5.3.2  Energy Transition            1
# 5          Text               5.3.2  Energy Transition            1
# 6     Text-wide               5.3.2  Energy Transition            1
# 7          Text               5.3.2  Energy Transition            1
# 8          Text               5.3.2  Energy Transition            1
# 9          Text               5.3.2  Energy Transition            1
# 10         Text               5.3.2  Energy Transition            2
# 11    Photo-Box               5.3.2  Energy Transition            2
# 12         Text               5.3.2  Energy Transition            2
# 13         Text               5.3.2  Energy Transition            2
# 14         Text               5.3.2  Energy Transition            2
# 15      Diagram               5.3.2  Energy Transition            2
# 16         Text               5.3.2  Energy Transition            2
# 17         Text               5.3.2  Energy Transition            2
# 18  Text-dark-6               5.3.2  Energy Transition            2
# 19         Text               5.3.2  Energy Transition            2
# 20         Text               5.3.2  Energy Transition            2
# 21         Text               5.3.2  Energy Transition            2
# 22  Text-dark-4               5.3.2  Energy Transition            2
# 23         Text               5.3.2  Energy Transition            2
# 24      Photo-5               5.3.2  Energy Transition            2
# 25         Text               5.3.2  Energy Transition            2
# 26      Photo-5               5.3.2  Energy Transition            2
# 27         Text               5.3.2  Energy Transition            2
# 28                            5.3.2  Energy Transition            2
#
#                                  Slide Title  \
# 0
# 1   Innovation in the Just Energy Transition
# 2   Innovation in the Just Energy Transition
# 3   Innovation in the Just Energy Transition
# 4   Innovation in the Just Energy Transition
# 5   Innovation in the Just Energy Transition
# 6   Innovation in the Just Energy Transition
# 7   Innovation in the Just Energy Transition
# 8   Innovation in the Just Energy Transition
# 9   Innovation in the Just Energy Transition
# 10                             Energy Access
# 11                             Energy Access
# 12                             Energy Access
# 13                             Energy Access
# 14                             Energy Access
# 15                             Energy Access
# 16                             Energy Access
# 17                             Energy Access
# 18                             Energy Access
# 19                             Energy Access
# 20                             Energy Access
# 21                             Energy Access
# 22                             Energy Access
# 23                             Energy Access
# 24                             Energy Access
# 25                             Energy Access
# 26                             Energy Access
# 27                             Energy Access
# 28                             Energy Access
#
#                                                  Text  Order
# 0                                   Energy Transition      1
# 1            Innovation in the Just Energy Transition      2
# 2                                           **Photo**      3
# 3                                        img=access-1      4
# 4                                     **Text-narrow**      5
# 5   Energy lorem ipsum alo vil cu li li oppo energ...      6
# 6                                       **Text-wide**      7
# 7            Energy lorem ipsum alo vil cu li li oppo      8
# 8   Energy lorem ipsum alo vil cu li li oppo energ...      9
# 9   Energy lorem ipsum alo vil cu li li oppo energ...     10
# 10                                      Energy Access     11
# 11                                      **Photo-Box**     12
# 12                                       img=access-3     13
# 13                                           **Text**     14
# 14                         Energy lorem ipsum alo vil     15
# 15                                        **Diagram**     16
# 16                                   dgm=transition-2     17
# 17  Here the diagram shows that renewable energy i...     18
# 18                                    **Text-dark-6**     19
# 19  Energy lorem ipsum alo vil cu li li oppo energ...     20
# 20  Energy lorem ipsum alo vil cu li li oppo energ...     21
# 21  Energy lorem ipsum alo vil cu li li oppo energ...     22
# 22                                    **Text-dark-4**     23
# 23  Energy lorem ipsum alo vil cu li li oppo energ...     24
# 24                                        **Photo-5**     25
# 25                                       img=access-1     26
# 26                                        **Photo-5**     27
# 27                                       img=access-1     28
# 28                                              *****     29

# %% [markdown]
#  Using NLP library to identify sentences and paragraphs

# %%
# python -m spacy download en_core_web_sm
import spacy

# %%
# Load the spaCy model for natural language processing
nlp = spacy.load('en_core_web_sm')
