# %% [markdown]
# # Energy Academy Pipeline
#
# ## Main
#
# This notebook serves as a brief introduction to the pipeline to extract content for Energy Academy using Figma API.

# %% [markdown]
# ### Libraries

# %%
from dotenv import load_dotenv

import sea

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Figma Document

# %%
# set the Figma file key
document = sea.Document.from_file_key("B33htro1nAvDFgFC4TpwC7")
print(document)  # display the node structure in a tree-like format
# Out:
# | DOCUMENT (Document)
# |- CANVAS (Page 1 (clean ver))
# |-- SECTION (Module 1 Intro)
# |--- FRAME (module_cover)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- GROUP (module)
# |----- TEXT (label)
# |----- TEXT (number)
# |---- TEXT (title)
# |---- TEXT (cta)
# |---- GROUP (Decoratives_ignore)
# |----- VECTOR (Line 269)
# |--- FRAME (text)
# |---- GROUP (subtitle)
# |----- TEXT (text)
# |---- GROUP (subtitle_small)
# |----- TEXT (text)
# |---- GROUP (paragraph_large)
# |----- TEXT (text)
# |--- FRAME (learning_objectives)
# |---- TEXT (title)
# |---- TEXT (intro)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (nature)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (decoratives_ignore)
# |----- TEXT (1.)
# |----- TEXT (2)
# |----- TEXT (3.)
# |--- FRAME (connection_next)
# |---- GROUP (Decoratives_ignore)
# |----- RECTANGLE (Background image)
# |---- FRAME (Decoratives_ignore)
# |----- FRAME (Frame 1171277114)
# |------ FRAME (Button/Primary)
# |------- VECTOR (Path 637)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (intro)
# |---- TEXT (title)
# |---- TEXT (cta)
# |--- FRAME (photo-full-height)
# |---- RECTANGLE (imageUrl)
# |-- SECTION (Chapter, Lesson, and Part)
# |--- SECTION (Chapter 1 Intro)
# |---- FRAME (chapter_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- GROUP (chapter)
# |------ TEXT (number)
# |------ TEXT (label)
# |----- TEXT (intro)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 269)
# |------ VECTOR (Line 269)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (list_of_lessons)
# |----- TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 272_ignore)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |---- FRAME (connection_next)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (Background image)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Button/Primary)
# |-------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |--- SECTION (Lesson 1.1)
# |---- FRAME (lesson_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- GROUP (lesson)
# |------ TEXT (label)
# |------ TEXT (number)
# |----- TEXT (title)
# |---- FRAME (quote_large_with_name)
# |----- TEXT (quote)
# |----- TEXT (author)
# |----- GROUP (Decoratives_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (key_takeaways)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (nature)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |----- GROUP (decoratives_ignore)
# |------ TEXT (1.)
# |------ TEXT (2)
# |------ TEXT (3.)
# |---- FRAME (key_resources)
# |----- TEXT (title)
# |----- GROUP (resources)
# |------ RECTANGLE (image)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (Renewable Innovations in the Public and Private Sector)
# |---- FRAME (connection_next)
# |----- FRAME (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Frame 1171277313)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (lesson_part_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- TEXT (title)
# |---- FRAME (photo-vertical)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (caption)
# |----- GROUP (decorative_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (key_concepts)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ VECTOR (Vector 275)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |------ TEXT (source)
# |--- SECTION (Chapter 1 Outro)
# |---- FRAME (chapter_outro)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |------ FRAME (Separator)
# |------ VECTOR (Vector 289)
# |----- TEXT (intro)
# |----- GROUP (quiz)
# |------ TEXT (intro)
# |------ TEXT (title)
# |------ TEXT (cta)
# |------ TEXT (buttonCta)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |----- GROUP (title)
# |------ TEXT (second_line)
# |------ TEXT (first_line)
# |----- TEXT (subtitle)
# |----- TEXT (body)
# |---- FRAME (connection_next)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |-- SECTION (Module 1 Outro)
# |--- FRAME (module_outro)
# |---- TEXT (intro)
# |---- GROUP (Decoratives_ignore)
# |----- FRAME (Decoratives_ignore)
# |------ VECTOR (Vector 289)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Decoratives_ignore)
# |------- FRAME (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |-------- FRAME (Frame 1171277319)
# |--------- FRAME (Subtitle)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |---- GROUP (quiz)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |----- TEXT (buttonCta)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |---- GROUP (title)
# |----- TEXT (first_line)
# |----- TEXT (second_line)
# |---- TEXT (subtitle)
# |---- TEXT (body)
# |--- FRAME (connection_next)
# |---- GROUP (Decoratives_ignore)
# |----- RECTANGLE (nature)
# |----- FRAME (Frame 1171277078)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (intro)
# |---- TEXT (title)
# |---- TEXT (cta)
# |- CANVAS (Page 2 (Updated strcutrue + notes))
# |-- FRAME (Click <clip content>to hide all comments)
# |--- VECTOR (Vector 290)
# |--- FRAME (learning_objectives)
# |---- RECTANGLE (Screenshot 2025-03-27 at 21.49.00 1)
# |--- RECTANGLE (Screenshot 2025-03-27 at 21.52.10 1)
# |--- RECTANGLE (Screenshot 2025-03-27 at 21.53.37 1)
# |--- FRAME (learning_objectives json / lesson_1.0.0)
# |---- RECTANGLE (Screenshot 2025-03-27 at 21.50.19 1)
# |--- VECTOR (Arrow 1)
# |--- VECTOR (Arrow 2)
# |--- TEXT (Hide all comments)
# |--- VECTOR (Vector 292)
# |--- VECTOR (Vector 291)
# |--- FRAME (module_cover / Original json)
# |---- RECTANGLE (Rectangle 1)
# |---- TEXT ({ "template_id": "module_cover", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "module": "Module 1", "title": "Introduction to the Energy Transition Landscape", "cta": "Scroll, tab or use your keyboard to move ahead" } },)
# |--- FRAME (module_cover / Need to be updated)
# |---- RECTANGLE (Rectangle 2)
# |---- TEXT ({ "template_id": "module_cover", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "module": { "label": “Module” "number": “1” }, "title": "Grounding M&E in the Local Context", "cta": "Scroll, tab or use your keyboard to move ahead" } })
# |--- FRAME (photo-full-height - question)
# |---- RECTANGLE (Screenshot 2025-03-27 at 21.45.32 1)
# |--- FRAME (photo-full-height - question)
# |---- RECTANGLE (Screenshot 2025-03-27 at 21.47.13 1)
# |--- TEXT (Hierarchy))
# |--- RECTANGLE (Screenshot 2025-03-27 at 21.41.44 1)
# |--- VECTOR (Vector 293)
# |--- FRAME (Original json)
# |---- RECTANGLE (Rectangle 1)
# |---- TEXT ({ "template_id": "chapter_cover", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "chapter": "C1", "intro": "Just Energy Transition | chapter 1", "title": "Introduction to the Energy Transition Landscape", "cta": "Scroll, tab or use your keyboard to move ahead" } },)
# |--- FRAME (Need to be updated)
# |---- RECTANGLE (Rectangle 2)
# |---- TEXT ({ "template_id": "chapter_cover", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "chapter": { "label": “Chapter” "number": “1” }, "intro": "Just Energy Transition | chapter 1", "title": "Introduction to the Energy Transition Landscape", "cta": "Scroll, tab or use your keyboard to move ahead" } },)
# |--- TEXT (Basic information) Decorative components are grouped and marked <decoratives_ignore>.)
# |--- RECTANGLE (Screenshot 2025-03-27 at 21.39.18 1)
# |--- TEXT (Requests) The caption doesn’t look visually strong at the moment. Would it be possible to apply a hover or click-to-reveal interaction instead? Module/chapter/lesson cover may requires json update. Please refer to the notes below those frames.)
# |--- VECTOR (Vector 293)
# |--- VECTOR (Vector 294)
# |--- FRAME (Original json)
# |---- RECTANGLE (Rectangle 1)
# |---- TEXT ({ "template_id": "lesson_cover", "colorscheme": "dark", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "lesson": "Lesson 1", "intro": "M1: <strong>Just Energy Transition</strong> | chapter 1 | lesson 1", "title": "Energy data, in planning, monitoring, and evaluation" } },)
# |--- FRAME (Need to be updated)
# |---- RECTANGLE (Rectangle 2)
# |---- TEXT ({ "template_id": "lesson_cover", "colorscheme": "dark", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "lesson": { "label": “Lesson” "number": “1” }, "intro": "M1: <strong>Just Energy Transition</strong> | chapter 1 | lesson 1", "title": "Energy data, in planning, monitoring, and evaluation" } },)
# |--- RECTANGLE (Rectangle 1)
# |--- FRAME (Original json)
# |---- TEXT ({ "template_id": "lesson_part_cover", "colorscheme": "dark", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "intro": "M1: <strong>Just Energy Transition</strong> | chapter 1 | Lesson 1 | Part 1", "part": "1", "title": "Part 1: How the triptych of data, digital, and AI are transforming energy policy and planning" } },)
# |--- FRAME (Need to be updated)
# |---- RECTANGLE (Rectangle 2)
# |---- TEXT ({ "template_id": "lesson_part_cover", "colorscheme": "dark", "content": { "image": { "src": "https://example.com/image.webp", "caption": "image caption" }, "intro": "M1: <strong>Just Energy Transition</strong> | chapter 1 | Lesson 1 | Part 1", "part": "1", "title": "Part 1: How the triptych of data, digital, and AI are transforming energy policy and planning" } },)
# |-- SECTION (Module 1 Intro)
# |--- FRAME (module_cover)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- GROUP (module)
# |----- TEXT (label)
# |----- TEXT (number)
# |---- TEXT (title)
# |---- TEXT (cta)
# |---- GROUP (Decoratives_ignore)
# |----- VECTOR (Line 269)
# |--- FRAME (text)
# |---- GROUP (subtitle)
# |----- TEXT (text)
# |---- GROUP (subtitle_small)
# |----- TEXT (text)
# |---- GROUP (paragraph_large)
# |----- TEXT (text)
# |--- FRAME (learning_objectives)
# |---- TEXT (title)
# |---- TEXT (intro)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (1. title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (nature)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |--- FRAME (connection_next)
# |---- GROUP (Decoratives_ignore)
# |----- RECTANGLE (Background image)
# |---- FRAME (Decoratives_ignore)
# |----- FRAME (Frame 1171277114)
# |------ FRAME (Button/Primary)
# |------- VECTOR (Path 637)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (intro)
# |---- TEXT (title)
# |---- TEXT (cta)
# |--- FRAME (photo-full-height)
# |---- RECTANGLE (imageUrl)
# |-- SECTION (Chapter 1)
# |--- SECTION (Chapter 1 Intro)
# |---- FRAME (chapter_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- GROUP (chapter)
# |------ TEXT (number)
# |------ TEXT (label)
# |----- TEXT (intro)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 269)
# |------ VECTOR (Line 269)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (list_of_lessons)
# |----- TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 272_ignore)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |---- FRAME (connection_next)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (Background image)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Button/Primary)
# |-------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |--- SECTION (Lesson 1.1)
# |---- FRAME (lesson_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- GROUP (lesson)
# |------ TEXT (label)
# |------ TEXT (number)
# |----- TEXT (title)
# |---- FRAME (quote_large_with_name)
# |----- TEXT (quote)
# |----- TEXT (author)
# |----- GROUP (Decoratives_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (key_takeaways)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (1. title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (nature)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |---- FRAME (key_resources)
# |----- TEXT (title)
# |----- GROUP (resources)
# |------ RECTANGLE (image)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (Renewable Innovations in the Public and Private Sector)
# |---- FRAME (connection_next)
# |----- FRAME (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Frame 1171277313)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (lesson_part_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- TEXT (title)
# |---- FRAME (photo-vertical)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (caption)
# |----- GROUP (decorative_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (key_concepts)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ VECTOR (Vector 275)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |------ TEXT (source)
# |--- SECTION (Chapter 1 Outro)
# |---- FRAME (chapter_outro)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |------ FRAME (Separator)
# |------ VECTOR (Vector 289)
# |----- TEXT (intro)
# |----- GROUP (quiz)
# |------ TEXT (intro)
# |------ TEXT (title)
# |------ TEXT (cta)
# |------ TEXT (buttonCta)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |----- GROUP (title)
# |------ TEXT (second_line)
# |------ TEXT (first_line)
# |----- TEXT (subtitle)
# |----- TEXT (body)
# |---- FRAME (connection_next)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |-- SECTION (Module 1 Outro)
# |--- FRAME (module_outro)
# |---- TEXT (intro)
# |---- GROUP (Decoratives_ignore)
# |----- FRAME (Decoratives_ignore)
# |------ VECTOR (Vector 289)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Decoratives_ignore)
# |------- FRAME (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |-------- FRAME (Frame 1171277319)
# |--------- FRAME (Subtitle)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |---- GROUP (quiz)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |----- TEXT (buttonCta)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |---- GROUP (title)
# |----- TEXT (first_line)
# |----- TEXT (second_line)
# |---- TEXT (subtitle)
# |---- TEXT (body)
# |--- FRAME (connection_next)
# |---- FRAME (Connection modules)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |-- SECTION (Templates need to be developed))
# |--- LINE (Line 29)
# |--- LINE (Line 28)
# |--- TEXT (Potential json)
# |--- TEXT (Templates need to be developed)
# |--- LINE (Line 24)
# |--- RECTANGLE (Screenshot 2025-03-27 at 22.45.12 1)
# |--- VECTOR (Arrow 2)
# |--- FRAME (bullets)
# |---- TEXT (title)
# |---- TEXT (intro)
# |---- GROUP (item)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (item)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (items)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |--- FRAME (bullets)
# |---- TEXT (title)
# |---- TEXT (intro)
# |---- GROUP (item)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (item)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (items)
# |----- TEXT (marker)
# |----- TEXT (title)
# |----- TEXT (description)
# |--- RECTANGLE (Screenshot 2025-03-27 at 22.44.00 1)
# |--- TEXT (Could unify the template for bullet/ numbered : Using <marker> to put number or bullet)
# |--- VECTOR (Arrow 1)
# |--- LINE (Line 25)
# |--- RECTANGLE (Screenshot 2025-03-27 at 22.56.28 1)
# |--- FRAME (accordion)
# |---- TEXT (heading)
# |---- GROUP (Decoratives_ignore)
# |----- RECTANGLE (Rectangle 75)
# |----- RECTANGLE (Rectangle 77)
# |----- LINE (Line 14)
# |----- LINE (Line 15)
# |----- RECTANGLE (Rectangle 81)
# |----- RECTANGLE (Rectangle 82)
# |----- LINE (Line 18)
# |----- LINE (Line 19)
# |----- RECTANGLE (Rectangle 83)
# |----- RECTANGLE (Rectangle 84)
# |----- LINE (Line 20)
# |----- LINE (Line 21)
# |----- RECTANGLE (Rectangle 85)
# |----- RECTANGLE (Rectangle 86)
# |----- LINE (Line 22)
# |----- LINE (Line 23)
# |---- GROUP (items)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (items)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (items)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (items)
# |----- TEXT (title)
# |----- TEXT (description)
# |--- LINE (Line 26)
# |--- FRAME (video-full-height)
# |---- RECTANGLE (image)
# |--- RECTANGLE (Screenshot 2025-03-27 at 22.36.19 1)
# |--- TEXT (same as photo-full-height but video url instead)
# |--- LINE (Line 27)
# |--- FRAME (subpart_cover)
# |---- RECTANGLE (UNDP-South-Sudan-2018_solar_panels_4902_2)
# |---- TEXT (B)
# |---- TEXT (Ensuring Sustainable Batteries Management)
# |---- TEXT (image_4:earth)
# |--- TEXT (A new design is required.)
# |--- LINE (Line 30)
# |- CANVAS (Backup (Original Page 1))
# |-- SECTION (Module 1 Intro)
# |--- FRAME (module_cover)
# |---- INSTANCE (Cover)
# |----- INSTANCE (Modules/ImageL)
# |------ RECTANGLE (nature)
# |----- FRAME (Tile-box)
# |------ FRAME (Frame 1171277449)
# |------- TEXT (module)
# |------- TEXT (1)
# |------ INSTANCE (Modules/Titles)
# |------- TEXT (Name of the module: Multiple line chapter title)
# |------ FRAME (Frame 1171277307)
# |------- INSTANCE (Cta-scroll)
# |-------- TEXT (Scroll, tab or use your keyboard to move ahead)
# |-------- VECTOR (Line 269)
# |--- FRAME (text)
# |---- FRAME (Frame 1171277061)
# |----- INSTANCE (Modules/Paragraph)
# |------ FRAME (Subtitle)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------ FRAME (Frame 1171277318)
# |------- FRAME (Subtitle)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |----- INSTANCE (Modules/Paragraph)
# |------ FRAME (Frame 1171277318)
# |------- FRAME (Subtitle)
# |--- INSTANCE (Key takeaways-Learning Objectives)
# |---- FRAME (Frame 1171277033)
# |----- INSTANCE (Modules/Paragraph)
# |------ FRAME (Subtitle)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------ FRAME (Frame 1171277318)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |---- FRAME (Frame 1171277096)
# |----- FRAME (Frame 1171277095)
# |------ INSTANCE (Modules/ImageXS)
# |------- RECTANGLE (nature)
# |------ INSTANCE (Modules/bulletpoint)
# |------- TEXT (1.)
# |------- FRAME (Frame 1171277333)
# |-------- TEXT (Lorem ipsum)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |----- FRAME (Frame 1171277095)
# |------ INSTANCE (Modules/ImageXS)
# |------- RECTANGLE (nature)
# |------ INSTANCE (Modules/bulletpoint)
# |------- TEXT (1.)
# |------- FRAME (Frame 1171277333)
# |-------- TEXT (Lorem ipsum)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |----- FRAME (Frame 1171277095)
# |------ INSTANCE (Modules/ImageXS)
# |------- RECTANGLE (nature)
# |------ INSTANCE (Modules/bulletpoint)
# |------- TEXT (1.)
# |------- FRAME (Frame 1171277333)
# |-------- TEXT (Lorem ipsum)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |--- FRAME (connection_next)
# |---- INSTANCE (Connection modules)
# |----- RECTANGLE (nature)
# |----- FRAME (Frame 1171277078)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Frame 1171277313)
# |-------- TEXT (Next up)
# |-------- TEXT (Lesson 1:Energy Data in Planning, Monitoring, and Evaluation)
# |------- INSTANCE (Button/Primary)
# |-------- INSTANCE (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |-------- TEXT (CTA Text)
# |--- FRAME (photo-full-height)
# |---- INSTANCE (Modules/ImageL)
# |----- RECTANGLE (nature)
# |-- SECTION (Module 1 Intro)
# |--- FRAME (module_cover)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- GROUP (module)
# |----- TEXT (label)
# |----- TEXT (number)
# |---- TEXT (title)
# |---- TEXT (cta)
# |---- GROUP (Decoratives_ignore)
# |----- VECTOR (Line 269)
# |--- FRAME (text)
# |---- GROUP (subtitle)
# |----- TEXT (text)
# |---- GROUP (subtitle_small)
# |----- TEXT (text)
# |---- GROUP (paragraph_large)
# |----- TEXT (text)
# |--- FRAME (learning_objectives)
# |---- TEXT (title)
# |---- TEXT (intro)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (nature)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (objectives)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (title)
# |----- TEXT (description)
# |---- GROUP (decoratives_ignore)
# |----- TEXT (1.)
# |----- TEXT (2)
# |----- TEXT (3.)
# |--- FRAME (Connection modules)
# |---- GROUP (Decoratives_ignore)
# |----- RECTANGLE (Background image)
# |---- FRAME (Decoratives_ignore)
# |----- FRAME (Frame 1171277114)
# |------ FRAME (Button/Primary)
# |------- VECTOR (Path 637)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (intro)
# |---- TEXT (title)
# |---- TEXT (cta)
# |--- FRAME (photo-full-height)
# |---- RECTANGLE (imageUrl)
# |-- SECTION (Chapter 1)
# |--- SECTION (Chapter 1 Intro)
# |---- FRAME (chapter_cover)
# |----- INSTANCE (Cover)
# |------ FRAME (Frame 1171276979)
# |------- FRAME (Frame 1171277310)
# |-------- FRAME (Frame 1171277448)
# |--------- TEXT (chapter)
# |--------- TEXT (1)
# |-------- FRAME (Frame 1171277309)
# |--------- FRAME (Frame 1171276938)
# |---------- TEXT (M1: Just Energy Transition | chapter 1)
# |---------- LINE (Line 269)
# |--------- INSTANCE (Modules/Titles)
# |---------- TEXT (Name of the module: Multiple line chapter title)
# |------- FRAME (Frame 1171277311)
# |-------- INSTANCE (Cta-scroll)
# |--------- TEXT (Scroll, tab or use your keyboard to move ahead)
# |--------- VECTOR (Line 269)
# |------ INSTANCE (Modules/ImageL)
# |------- RECTANGLE (nature)
# |---- LINE (Line 271)
# |---- FRAME (text)
# |----- FRAME (Frame 1171277311)
# |------ FRAME (Chapter Overview)
# |------- FRAME (SVG)
# |------- FRAME (Frame 1171277061)
# |-------- INSTANCE (Modules/Paragraph)
# |--------- FRAME (Subtitle)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |--------- FRAME (Frame 1171277318)
# |---------- FRAME (Subtitle)
# |----------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |------- FRAME (SVG)
# |-------- INSTANCE (Component 1)
# |--------- VECTOR (Vector)
# |---- FRAME (list_of_lessons)
# |----- INSTANCE (List-Of-Lessons)
# |------ FRAME (Frame 1171277029)
# |------- FRAME (Frame 1171277033)
# |-------- INSTANCE (Modules/Paragraph)
# |--------- FRAME (Subtitle)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------- FRAME (Frame 1171277050)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277045)
# |---------- INSTANCE (type of lesson)
# |----------- VECTOR (Rectangle 193 (Stroke))
# |----------- RECTANGLE (Rectangle 311)
# |---------- TEXT (1.1 Energy Data in Monitoring and Evaluation)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277045)
# |---------- INSTANCE (type of lesson)
# |----------- VECTOR (Rectangle 193 (Stroke))
# |----------- RECTANGLE (Rectangle 311)
# |---------- TEXT (1.1 Energy Data in Monitoring and Evaluation)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277045)
# |---------- INSTANCE (type of lesson)
# |----------- VECTOR (Rectangle 193 (Stroke))
# |---------- TEXT (1.1 Energy Data in Monitoring and Evaluation)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277045)
# |---------- INSTANCE (type of lesson)
# |----------- VECTOR (Rectangle 193 (Stroke))
# |---------- TEXT (1.1 Energy Data in Monitoring and Evaluation)
# |-------- LINE (Line 272)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277045)
# |---------- INSTANCE (type of lesson)
# |----------- GROUP (Layer 1)
# |------------ VECTOR (Vector (Stroke))
# |---------- TEXT (1.1 Energy Data in Monitoring and Evaluation)
# |---- INSTANCE (Connection modules)
# |----- RECTANGLE (nature)
# |----- FRAME (Frame 1171277078)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Frame 1171277313)
# |-------- TEXT (Next up)
# |-------- TEXT (Lesson 1:Energy Data in Planning, Monitoring, and Evaluation)
# |------- INSTANCE (Button/Primary)
# |-------- INSTANCE (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |-------- TEXT (CTA Text)
# |--- SECTION (Lesson 1.1)
# |---- FRAME (lesson_cover)
# |----- INSTANCE (Cover)
# |------ FRAME (Frame 1171277283)
# |------- FRAME (Frame 1171277446)
# |-------- TEXT (lesson)
# |-------- TEXT (1)
# |------ FRAME (Frame 1171277079)
# |------- FRAME (Frame 1171277067)
# |-------- FRAME (Frame 1171276938)
# |--------- TEXT (M1: Just Energy Transition | chapter 1 | Lesson 1)
# |--------- LINE (Line 269)
# |-------- INSTANCE (Modules/Titles)
# |--------- TEXT (Name of the module: Multiple line chapter title)
# |------ INSTANCE (Modules/ImageL)
# |------- RECTANGLE (nature)
# |------ RECTANGLE (Space)
# |---- FRAME (key_concepts)
# |----- INSTANCE (Key concepts)
# |------ FRAME (Frame 1171277033)
# |------- INSTANCE (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |-------- FRAME (Frame 1171277319)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |------ FRAME (Frame 1171277348)
# |------- FRAME (Frame 1171277096)
# |-------- FRAME (Frame 1171277072)
# |--------- INSTANCE (Modules/bulletpoint)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |-------- FRAME (Frame 1171277073)
# |--------- INSTANCE (Modules/bulletpoint)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |-------- FRAME (Frame 1171277074)
# |--------- INSTANCE (Modules/bulletpoint)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |--------- INSTANCE (Modules)
# |---------- TEXT (Caption)
# |---------- VECTOR (Vector 275)
# |------ FRAME (SVG)
# |------- INSTANCE (Component 1)
# |-------- VECTOR (Vector)
# |---- FRAME (text)
# |----- INSTANCE (Modules/Quote)
# |------ TEXT (“Lorem ipsum dolor sit amet consectetur. Est a sagittis mi amet elementum volutpat amet nibh porttitor.”)
# |------ FRAME (Author)
# |------- TEXT (Name Surname)
# |------- VECTOR (Vector 275)
# |----- INSTANCE (Modules/Paragraph)
# |------ FRAME (Frame 1171277319)
# |---- FRAME (text)
# |----- INSTANCE (Modules/Paragraph)
# |------ FRAME (Subtitle)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------ FRAME (Frame 1171277319)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |----- INSTANCE (Modules/bulletpoint)
# |------ TEXT (1.)
# |------ FRAME (Frame 1171277333)
# |------- TEXT (Lorem ipsum)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |----- INSTANCE (Modules/bulletpoint)
# |------ TEXT (1.)
# |------ FRAME (Frame 1171277333)
# |------- TEXT (Lorem ipsum)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |----- INSTANCE (Modules/bulletpoint)
# |------ TEXT (1.)
# |------ FRAME (Bullet)
# |------- TEXT (Lorem ipsum)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |---- FRAME (key_takeaways)
# |----- INSTANCE (Key takeaways-Learning Objectives)
# |------ FRAME (Frame 1171277033)
# |------- INSTANCE (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |-------- FRAME (Frame 1171277318)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |------ FRAME (Frame 1171277096)
# |------- FRAME (Frame 1171277095)
# |-------- INSTANCE (Modules/ImageXS)
# |--------- RECTANGLE (nature)
# |-------- INSTANCE (Modules/bulletpoint)
# |--------- TEXT (1.)
# |--------- FRAME (Frame 1171277333)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |------- FRAME (Frame 1171277095)
# |-------- INSTANCE (Modules/ImageXS)
# |--------- RECTANGLE (nature)
# |-------- INSTANCE (Modules/bulletpoint)
# |--------- TEXT (1.)
# |--------- FRAME (Frame 1171277333)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |------- FRAME (Frame 1171277095)
# |-------- INSTANCE (Modules/ImageXS)
# |--------- RECTANGLE (nature)
# |-------- INSTANCE (Modules/bulletpoint)
# |--------- TEXT (1.)
# |--------- FRAME (Frame 1171277333)
# |---------- TEXT (Lorem ipsum)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate.)
# |---- FRAME (key_resources)
# |----- INSTANCE (Key-Resources)
# |------ FRAME (Frame 1171277029)
# |------- FRAME (Frame 1171277033)
# |-------- TEXT (Key resources)
# |------- FRAME (Frame 1171277050)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277046)
# |---------- TEXT (Renewable Innovations in the Public and Private Sector)
# |-------- LINE (Line 273)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277046)
# |---------- TEXT (Renewable Innovations in the Public and Private Sector)
# |-------- LINE (Line 272)
# |-------- INSTANCE (Card/Selector-inside-a-lesson)
# |--------- RECTANGLE (image_3)
# |--------- FRAME (Frame 1171277046)
# |---------- TEXT (Renewable Innovations in the Public and Private Sector)
# |---- FRAME (lesson_part_cover)
# |----- INSTANCE (Cover)
# |------ INSTANCE (Modules/ImageL)
# |------- RECTANGLE (nature)
# |------ FRAME (Frame 1171277083)
# |------- FRAME (Frame 1171277079)
# |-------- FRAME (Frame 1171277067)
# |--------- FRAME (Frame 1171276937)
# |---------- TEXT (M1: Just Energy Transition | chapter 1 | Lesson 1 | Part 1)
# |---------- LINE (Line 269)
# |--------- INSTANCE (Modules/Titles)
# |---------- TEXT (Name of the module: Multiple line chapter title)
# |---- FRAME (photo-vertical)
# |----- INSTANCE (Modules/ImageM)
# |------ RECTANGLE (nature)
# |------ INSTANCE (Modules)
# |------- TEXT (Caption)
# |------- VECTOR (Vector 275)
# |---- FRAME (connection_next)
# |----- INSTANCE (Connection modules)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- RECTANGLE (nature)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Frame 1171277313)
# |--------- TEXT (Next up)
# |--------- TEXT (Lesson 1:Energy Data in Planning, Monitoring, and Evaluation)
# |-------- INSTANCE (Button/Primary)
# |--------- INSTANCE (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |--------- TEXT (CTA Text)
# |---- FRAME (text)
# |----- FRAME (Modules/Paragraph)
# |------ FRAME (Subtitle)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------ FRAME (Frame 1171277318)
# |------- FRAME (Subtitle)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |--- SECTION (Chapter 1 Outro)
# |---- FRAME (chapter_outro)
# |----- INSTANCE (End)
# |------ FRAME (Interactive-scenario)
# |------- FRAME (Frame)
# |-------- INSTANCE (Modules/Paragraph)
# |--------- FRAME (Subtitle)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |--------- FRAME (Frame 1171277319)
# |---------- FRAME (Subtitle)
# |----------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |-------- INSTANCE (Button/Primary)
# |--------- INSTANCE (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |--------- TEXT (CTA Text)
# |------- RECTANGLE (Img)
# |------ FRAME (Conclusion)
# |------- FRAME (Title)
# |-------- TEXT (This concludes)
# |-------- INSTANCE (Modules/Titles)
# |--------- TEXT (Name of the module: Multiple line chapter title)
# |------- INSTANCE (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |-------- FRAME (Frame 1171277319)
# |--------- FRAME (Subtitle)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |------ INSTANCE (Separator)
# |------- VECTOR (Vector 289)
# |---- FRAME (connection_next)
# |----- INSTANCE (Connection modules)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- RECTANGLE (nature)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Frame 1171277313)
# |--------- TEXT (Next up)
# |--------- TEXT (Lesson 1:Energy Data in Planning, Monitoring, and Evaluation)
# |-------- INSTANCE (Button/Primary)
# |--------- INSTANCE (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |--------- TEXT (CTA Text)
# |-- SECTION (Chapter 2)
# |--- SECTION (Chapter 1 Intro)
# |---- FRAME (chapter_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- GROUP (chapter)
# |------ TEXT (number)
# |------ TEXT (label)
# |----- TEXT (intro)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 269)
# |------ VECTOR (Line 269)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (list_of_lessons)
# |----- TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ RECTANGLE (progress)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |----- GROUP (Decoratives_ignore)
# |------ LINE (Line 272_ignore)
# |----- GROUP (lessons)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ VECTOR (type)
# |------ TEXT (title)
# |---- FRAME (Connection modules)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (Background image)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Button/Primary)
# |-------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |--- SECTION (Lesson 1.1)
# |---- FRAME (lesson_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- GROUP (lesson)
# |------ TEXT (label)
# |------ TEXT (number)
# |----- TEXT (title)
# |---- FRAME (quote_large_with_name)
# |----- TEXT (quote)
# |----- TEXT (author)
# |----- GROUP (Decoratives_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (key_takeaways)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (1. title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (nature)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |----- GROUP (objectives)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (title)
# |------ TEXT (description)
# |---- FRAME (key_resources)
# |----- TEXT (title)
# |----- GROUP (resources)
# |------ RECTANGLE (image)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (text)
# |----- GROUP (resources)
# |------ RECTANGLE (image_3)
# |------ TEXT (Renewable Innovations in the Public and Private Sector)
# |---- FRAME (connection_next)
# |----- FRAME (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Frame 1171277313)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |---- FRAME (lesson_part_cover)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ LINE (Line 269_ignore)
# |----- TEXT (title)
# |---- FRAME (photo-vertical)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (caption)
# |----- GROUP (decorative_ignore)
# |------ VECTOR (Vector 275)
# |---- FRAME (text)
# |----- GROUP (subtitle)
# |------ TEXT (text)
# |----- GROUP (subtitle_small)
# |------ TEXT (text)
# |----- GROUP (paragraph_large)
# |------ TEXT (text)
# |---- FRAME (key_concepts)
# |----- TEXT (title)
# |----- TEXT (intro)
# |----- GROUP (decoratives_ignore)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ FRAME (Modules/bulletpoint)
# |------ VECTOR (Vector 275)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |----- GROUP (concepts)
# |------ TEXT (title)
# |------ TEXT (body)
# |------ TEXT (source)
# |--- SECTION (Chapter 1 Outro)
# |---- FRAME (chapter_outro)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Frame)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |------ FRAME (Separator)
# |------ VECTOR (Vector 289)
# |----- TEXT (intro)
# |----- GROUP (quiz)
# |------ TEXT (intro)
# |------ TEXT (title)
# |------ TEXT (cta)
# |------ TEXT (buttonCta)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |----- GROUP (title)
# |------ TEXT (second_line)
# |------ TEXT (first_line)
# |----- TEXT (subtitle)
# |----- TEXT (body)
# |---- FRAME (connection_next)
# |----- FRAME (Connection modules)
# |------ GROUP (Decoratives_ignore)
# |------- RECTANGLE (nature)
# |------- FRAME (Frame 1171277078)
# |-------- FRAME (Frame 1171277114)
# |--------- FRAME (Button/Primary)
# |---------- FRAME (Chevrons / Chevron small right)
# |----------- VECTOR (Path 637)
# |------ GROUP (image)
# |------- RECTANGLE (src)
# |------- TEXT (caption)
# |------ TEXT (intro)
# |------ TEXT (title)
# |------ TEXT (cta)
# |-- SECTION (Module 1 Outro)
# |--- FRAME (module_outro)
# |---- INSTANCE (End)
# |----- FRAME (Conclusion)
# |------ FRAME (Title)
# |------- TEXT (Congratulations, you have concluded)
# |------- INSTANCE (Modules/Titles)
# |-------- TEXT (Name of the module: Multiple line chapter title)
# |------ INSTANCE (Modules/Paragraph)
# |------- FRAME (Subtitle)
# |------- FRAME (Frame 1171277319)
# |-------- FRAME (Subtitle)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |-------- TEXT (Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.)
# |----- INSTANCE (Separator)
# |------ VECTOR (Vector 289)
# |----- FRAME (Interactive-scenario)
# |------ FRAME (Frame)
# |------- INSTANCE (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |--------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |-------- FRAME (Frame 1171277319)
# |--------- FRAME (Subtitle)
# |---------- TEXT (Lorem ipsum dolor sit amet consectetur)
# |------- INSTANCE (Button/Primary)
# |-------- INSTANCE (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |-------- TEXT (CTA Text)
# |------ RECTANGLE (Img)
# |--- FRAME (connection_next)
# |---- INSTANCE (Connection modules)
# |----- RECTANGLE (nature)
# |----- FRAME (Frame 1171277078)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277114)
# |------- FRAME (Frame 1171277313)
# |-------- TEXT (Next up)
# |-------- TEXT (Lesson 1:Energy Data in Planning, Monitoring, and Evaluation)
# |------- INSTANCE (Button/Primary)
# |-------- INSTANCE (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |-------- TEXT (CTA Text)
# |-- SECTION (Module 1 Outro)
# |--- FRAME (module_outro)
# |---- TEXT (intro)
# |---- GROUP (Decoratives_ignore)
# |----- FRAME (Decoratives_ignore)
# |------ VECTOR (Vector 289)
# |----- FRAME (Decoratives_ignore)
# |------ FRAME (Decoratives_ignore)
# |------- FRAME (Modules/Paragraph)
# |-------- FRAME (Subtitle)
# |-------- FRAME (Frame 1171277319)
# |--------- FRAME (Subtitle)
# |------- FRAME (Button/Primary)
# |-------- FRAME (Chevrons / Chevron small right)
# |--------- VECTOR (Path 637)
# |---- GROUP (quiz)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)
# |----- TEXT (buttonCta)
# |----- GROUP (imaage)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |---- GROUP (title)
# |----- TEXT (first_line)
# |----- TEXT (second_line)
# |---- TEXT (subtitle)
# |---- TEXT (body)
# |--- FRAME (connection_next)
# |---- FRAME (Connection modules)
# |----- GROUP (Decoratives_ignore)
# |------ RECTANGLE (nature)
# |------ FRAME (Frame 1171277078)
# |------- FRAME (Frame 1171277114)
# |-------- FRAME (Button/Primary)
# |--------- FRAME (Chevrons / Chevron small right)
# |---------- VECTOR (Path 637)
# |----- GROUP (image)
# |------ RECTANGLE (src)
# |------ TEXT (caption)
# |----- TEXT (intro)
# |----- TEXT (title)
# |----- TEXT (cta)

# %%
# the underlying method provides more control through the depth parameter
document.display(depth=2)
# Out:
# | DOCUMENT (Document)
# |- CANVAS (Page 1 (clean ver))
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter, Lesson, and Part)
# |-- SECTION (Module 1 Outro)
# |- CANVAS (Page 2 (Updated strcutrue + notes))
# |-- FRAME (Click <clip content>to hide all comments)
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter 1)
# |-- SECTION (Module 1 Outro)
# |-- SECTION (Templates need to be developed))
# |- CANVAS (Backup (Original Page 1))
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter 1)
# |-- SECTION (Chapter 2)
# |-- SECTION (Module 1 Outro)
# |-- SECTION (Module 1 Outro)

# %% [markdown]
# ### Module 1 Intro

# %%
module = document.select_node(type="SECTION", pattern="Module 1 Intro")
print(module)
# Out:
# | SECTION (Module 1 Intro)
# |- FRAME (module_cover)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- GROUP (module)
# |--- TEXT (label)
# |--- TEXT (number)
# |-- TEXT (title)
# |-- TEXT (cta)
# |-- GROUP (Decoratives_ignore)
# |--- VECTOR (Line 269)
# |- FRAME (text)
# |-- GROUP (subtitle)
# |--- TEXT (text)
# |-- GROUP (subtitle_small)
# |--- TEXT (text)
# |-- GROUP (paragraph_large)
# |--- TEXT (text)
# |- FRAME (learning_objectives)
# |-- TEXT (title)
# |-- TEXT (intro)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (nature)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (decoratives_ignore)
# |--- TEXT (1.)
# |--- TEXT (2)
# |--- TEXT (3.)
# |- FRAME (connection_next)
# |-- GROUP (Decoratives_ignore)
# |--- RECTANGLE (Background image)
# |-- FRAME (Decoratives_ignore)
# |--- FRAME (Frame 1171277114)
# |---- FRAME (Button/Primary)
# |----- VECTOR (Path 637)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)
# |- FRAME (photo-full-height)
# |-- RECTANGLE (imageUrl)

# %%
node = module.select_node("FRAME", "module_cover")
print(node)
# Out:
# | FRAME (module_cover)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- GROUP (module)
# |-- TEXT (label)
# |-- TEXT (number)
# |- TEXT (title)
# |- TEXT (cta)
# |- GROUP (Decoratives_ignore)
# |-- VECTOR (Line 269)

# %%
frame = sea.Cover.from_node(node)
frame.to_content()
# Out:
# {'id': 'module_cover',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': {'label': 'Module', 'number': '1'},
#   'title': 'Introduction to the Energy Transition Landscape',
#   'cta': 'Scroll, tab or use your keyboard to move ahead '}}

# %%
node = module.select_node("FRAME", "text")
print(node)
# Out:
# | FRAME (text)
# |- GROUP (subtitle)
# |-- TEXT (text)
# |- GROUP (subtitle_small)
# |-- TEXT (text)
# |- GROUP (paragraph_large)
# |-- TEXT (text)

# %%
frame = sea.ModuleText.from_node(node)
frame.to_content()
# Out:
# {'id': 'text',
#  'colorscheme': 'dark',
#  'content': {'content': [{'id': 'subtitle',
#     'colorscheme': None,
#     'text': 'Module Overview'},
#    {'id': 'subtitle_small',
#     'colorscheme': None,
#     'text': 'Lorem ipsum dolor sit amet consectetur'},
#    {'id': 'paragraph_large',
#     'colorscheme': None,
#     'text': 'Lorem ipsum dolor sit amet consectetur. Eget pulvinar ullamcorper elementum donec. Magna ac dignissim ac sed donec euismod. Vitae dui et eu tortor. Consectetur nullam ultricies in rhoncus sollicitudin purus vulputate. Sollicitudin sed nulla sit sed id iaculis tincidunt. Nunc elit nunc aliquam quis. Neque sagittis ultrices sagittis pulvinar mattis fames.'}]}}

# %%
node = module.select_node("FRAME", "learning_objectives")
print(node)
# Out:
# | FRAME (learning_objectives)
# |- TEXT (title)
# |- TEXT (intro)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (nature)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (decoratives_ignore)
# |-- TEXT (1.)
# |-- TEXT (2)
# |-- TEXT (3.)

# %%
frame = sea.LearningObjectives.from_node(node)
frame.to_content()
# Out:
# {'id': 'learning_objectives',
#  'colorscheme': None,
#  'content': {'title': 'Learning Objectives',
#   'intro': 'If you only have space to remember 3 things:',
#   'cards': [{'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': 'Monitoring progress towards sustainable energy goals\xa0is key.',
#     'description': "Monitoring the evolution of key indicators, such as the renewable energy share in total final energy consumption (e.g., indicator 7.2.1), provides vital insights into the progress toward sustainable energy goals. This data-driven approach enhances countries' ability to plan scenarios effectively in line with achieving global energy targets by 2030."},
#    {'image': {'src': 'nature', 'caption': 'image caption', 'url': None},
#     'title': 'Economic growth and energy policies\xa0are critical.',
#     'description': 'Data-driven analysis offers valuable evidence regarding the economic impacts of different energy policies, including effects on GDP, employment rates, and trade balances. Energy modellling, encompassing various methodologies such as econometric analysis and technology-rich accounting frameworks, serves as a crucial component in informing energy policy formulation.'},
#    {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': 'We must always be evaluating the environmental impact of sustainable energy development.',
#     'description': 'Integration of data on sustainable energy development with environmental datasets enables comprehensive assessments of environmental impacts and facilitates the monitoring of changes over time.'}]}}

# %%
frame = module.select_node("FRAME", "connection_next")
print(frame)
# Out:
# | FRAME (connection_next)
# |- GROUP (Decoratives_ignore)
# |-- RECTANGLE (Background image)
# |- FRAME (Decoratives_ignore)
# |-- FRAME (Frame 1171277114)
# |--- FRAME (Button/Primary)
# |---- VECTOR (Path 637)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- TEXT (title)
# |- TEXT (cta)

# %% [markdown]
# ### Chapter 1

# %%
chapter = document.select_node(type="SECTION", pattern="Chapter, Lesson, and Part")
print(chapter)
# Out:
# | SECTION (Chapter, Lesson, and Part)
# |- SECTION (Chapter 1 Intro)
# |-- FRAME (chapter_cover)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- GROUP (chapter)
# |---- TEXT (number)
# |---- TEXT (label)
# |--- TEXT (intro)
# |--- GROUP (Decoratives_ignore)
# |---- LINE (Line 269)
# |---- VECTOR (Line 269)
# |--- TEXT (title)
# |--- TEXT (cta)
# |-- FRAME (text)
# |--- GROUP (subtitle)
# |---- TEXT (text)
# |--- GROUP (subtitle_small)
# |---- TEXT (text)
# |--- GROUP (paragraph_large)
# |---- TEXT (text)
# |-- FRAME (list_of_lessons)
# |--- TEXT (title)
# |--- GROUP (lessons)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- VECTOR (type)
# |---- RECTANGLE (progress)
# |---- TEXT (title)
# |--- GROUP (lessons)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- VECTOR (type)
# |---- RECTANGLE (progress)
# |---- TEXT (title)
# |--- GROUP (lessons)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- VECTOR (type)
# |---- TEXT (title)
# |--- GROUP (lessons)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- VECTOR (type)
# |---- TEXT (title)
# |--- GROUP (Decoratives_ignore)
# |---- LINE (Line 272_ignore)
# |--- GROUP (lessons)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- VECTOR (type)
# |---- TEXT (title)
# |-- FRAME (connection_next)
# |--- GROUP (Decoratives_ignore)
# |---- RECTANGLE (Background image)
# |--- FRAME (Decoratives_ignore)
# |---- FRAME (Frame 1171277114)
# |----- FRAME (Button/Primary)
# |------ VECTOR (Path 637)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (intro)
# |--- TEXT (title)
# |--- TEXT (cta)
# |- SECTION (Lesson 1.1)
# |-- FRAME (lesson_cover)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (intro)
# |--- GROUP (decoratives_ignore)
# |---- LINE (Line 269_ignore)
# |--- GROUP (lesson)
# |---- TEXT (label)
# |---- TEXT (number)
# |--- TEXT (title)
# |-- FRAME (quote_large_with_name)
# |--- TEXT (quote)
# |--- TEXT (author)
# |--- GROUP (Decoratives_ignore)
# |---- VECTOR (Vector 275)
# |-- FRAME (key_takeaways)
# |--- TEXT (title)
# |--- TEXT (intro)
# |--- GROUP (objectives)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (title)
# |---- TEXT (description)
# |--- GROUP (objectives)
# |---- GROUP (image)
# |----- RECTANGLE (nature)
# |----- TEXT (caption)
# |---- TEXT (title)
# |---- TEXT (description)
# |--- GROUP (objectives)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |---- TEXT (title)
# |---- TEXT (description)
# |--- GROUP (decoratives_ignore)
# |---- TEXT (1.)
# |---- TEXT (2)
# |---- TEXT (3.)
# |-- FRAME (key_resources)
# |--- TEXT (title)
# |--- GROUP (resources)
# |---- RECTANGLE (image)
# |---- TEXT (text)
# |--- GROUP (resources)
# |---- RECTANGLE (image_3)
# |---- TEXT (text)
# |--- GROUP (resources)
# |---- RECTANGLE (image_3)
# |---- TEXT (Renewable Innovations in the Public and Private Sector)
# |-- FRAME (connection_next)
# |--- FRAME (Decoratives_ignore)
# |---- RECTANGLE (nature)
# |---- FRAME (Frame 1171277078)
# |----- FRAME (Frame 1171277114)
# |------ FRAME (Frame 1171277313)
# |------ FRAME (Button/Primary)
# |------- FRAME (Chevrons / Chevron small right)
# |-------- VECTOR (Path 637)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (intro)
# |--- TEXT (title)
# |--- TEXT (cta)
# |-- FRAME (lesson_part_cover)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (intro)
# |--- GROUP (decoratives_ignore)
# |---- LINE (Line 269_ignore)
# |--- TEXT (title)
# |-- FRAME (photo-vertical)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (caption)
# |--- GROUP (decorative_ignore)
# |---- VECTOR (Vector 275)
# |-- FRAME (text)
# |--- GROUP (subtitle)
# |---- TEXT (text)
# |--- GROUP (subtitle_small)
# |---- TEXT (text)
# |--- GROUP (paragraph_large)
# |---- TEXT (text)
# |-- FRAME (key_concepts)
# |--- TEXT (title)
# |--- TEXT (intro)
# |--- GROUP (decoratives_ignore)
# |---- FRAME (Modules/bulletpoint)
# |---- FRAME (Modules/bulletpoint)
# |---- FRAME (Modules/bulletpoint)
# |---- VECTOR (Vector 275)
# |--- GROUP (concepts)
# |---- TEXT (title)
# |---- TEXT (body)
# |--- GROUP (concepts)
# |---- TEXT (title)
# |---- TEXT (body)
# |--- GROUP (concepts)
# |---- TEXT (title)
# |---- TEXT (body)
# |---- TEXT (source)
# |- SECTION (Chapter 1 Outro)
# |-- FRAME (chapter_outro)
# |--- FRAME (Decoratives_ignore)
# |---- FRAME (Frame)
# |----- FRAME (Button/Primary)
# |------ FRAME (Chevrons / Chevron small right)
# |------- VECTOR (Path 637)
# |---- FRAME (Separator)
# |---- VECTOR (Vector 289)
# |--- TEXT (intro)
# |--- GROUP (quiz)
# |---- TEXT (intro)
# |---- TEXT (title)
# |---- TEXT (cta)
# |---- TEXT (buttonCta)
# |---- GROUP (image)
# |----- RECTANGLE (src)
# |----- TEXT (caption)
# |--- GROUP (title)
# |---- TEXT (second_line)
# |---- TEXT (first_line)
# |--- TEXT (subtitle)
# |--- TEXT (body)
# |-- FRAME (connection_next)
# |--- GROUP (Decoratives_ignore)
# |---- RECTANGLE (nature)
# |---- FRAME (Frame 1171277078)
# |----- FRAME (Frame 1171277114)
# |------ FRAME (Button/Primary)
# |------- FRAME (Chevrons / Chevron small right)
# |-------- VECTOR (Path 637)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (intro)
# |--- TEXT (title)
# |--- TEXT (cta)

# %% [markdown]
# #### Chapter Intro

# %%
chapter_intro = chapter.select_node("SECTION", "Chapter 1 Intro")
print(chapter_intro)
# Out:
# | SECTION (Chapter 1 Intro)
# |- FRAME (chapter_cover)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- GROUP (chapter)
# |--- TEXT (number)
# |--- TEXT (label)
# |-- TEXT (intro)
# |-- GROUP (Decoratives_ignore)
# |--- LINE (Line 269)
# |--- VECTOR (Line 269)
# |-- TEXT (title)
# |-- TEXT (cta)
# |- FRAME (text)
# |-- GROUP (subtitle)
# |--- TEXT (text)
# |-- GROUP (subtitle_small)
# |--- TEXT (text)
# |-- GROUP (paragraph_large)
# |--- TEXT (text)
# |- FRAME (list_of_lessons)
# |-- TEXT (title)
# |-- GROUP (lessons)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- VECTOR (type)
# |--- RECTANGLE (progress)
# |--- TEXT (title)
# |-- GROUP (lessons)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- VECTOR (type)
# |--- RECTANGLE (progress)
# |--- TEXT (title)
# |-- GROUP (lessons)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- VECTOR (type)
# |--- TEXT (title)
# |-- GROUP (lessons)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- VECTOR (type)
# |--- TEXT (title)
# |-- GROUP (Decoratives_ignore)
# |--- LINE (Line 272_ignore)
# |-- GROUP (lessons)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- VECTOR (type)
# |--- TEXT (title)
# |- FRAME (connection_next)
# |-- GROUP (Decoratives_ignore)
# |--- RECTANGLE (Background image)
# |-- FRAME (Decoratives_ignore)
# |--- FRAME (Frame 1171277114)
# |---- FRAME (Button/Primary)
# |----- VECTOR (Path 637)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)

# %%
node = chapter_intro.select_node("FRAME", "chapter_cover")
print(node)
# Out:
# | FRAME (chapter_cover)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- GROUP (chapter)
# |-- TEXT (number)
# |-- TEXT (label)
# |- TEXT (intro)
# |- GROUP (Decoratives_ignore)
# |-- LINE (Line 269)
# |-- VECTOR (Line 269)
# |- TEXT (title)
# |- TEXT (cta)

# %%
frame = sea.Cover.from_node(node)
frame.to_content()
# Out:
# {'id': 'chapter_cover',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': {'label': '1', 'number': 'chapter'},
#   'title': 'Introduction to the Energy Transition Landscape',
#   'cta': 'Scroll, tab or use your keyboard to move ahead '}}

# %%
node = chapter_intro.select_node("FRAME", "text")
print(node)
# Out:
# | FRAME (text)
# |- GROUP (subtitle)
# |-- TEXT (text)
# |- GROUP (subtitle_small)
# |-- TEXT (text)
# |- GROUP (paragraph_large)
# |-- TEXT (text)

# %%
frame = sea.ModuleText.from_node(node)
frame.to_content()
# Out:
# {'id': 'text',
#  'colorscheme': 'dark',
#  'content': {'content': [{'id': 'subtitle',
#     'colorscheme': None,
#     'text': 'Chapter 1 Overview'},
#    {'id': 'subtitle_small',
#     'colorscheme': None,
#     'text': 'Lorem ipsum dolor sit amet'},
#    {'id': 'paragraph_large',
#     'colorscheme': None,
#     'text': 'As climate change intensifies and reshapes our world, we need an energy revolution for a ‘just energy transition’. But what does this term truly mean beyond emission reduction? A just energy transition is more than a climate imperative; it is a moral and social responsibility that demands our attention.'}]}}

# %%
node = chapter_intro.select_node("FRAME", "list_of_lessons")
print(node)
# Out:
# | FRAME (list_of_lessons)
# |- TEXT (title)
# |- GROUP (lessons)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- VECTOR (type)
# |-- RECTANGLE (progress)
# |-- TEXT (title)
# |- GROUP (lessons)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- VECTOR (type)
# |-- RECTANGLE (progress)
# |-- TEXT (title)
# |- GROUP (lessons)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- VECTOR (type)
# |-- TEXT (title)
# |- GROUP (lessons)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- VECTOR (type)
# |-- TEXT (title)
# |- GROUP (Decoratives_ignore)
# |-- LINE (Line 272_ignore)
# |- GROUP (lessons)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- VECTOR (type)
# |-- TEXT (title)

# %%
frame = sea.LessonOverview.from_node(node)
frame.to_content()
# Out:
# {'id': 'list_of_lessons',
#  'colorscheme': None,
#  'content': {'title': "What's next in this chapter?",
#   'lessons': [{'cta': 'Go to the lesson',
#     'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': '1.1 Energy Data in Monitoring and Evaluation',
#     'progress': 'completed'},
#    {'cta': 'Go to the lesson',
#     'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': '1.2 Geospatial Data and Machine Learning',
#     'progress': 'completed'},
#    {'cta': 'Go to the lesson',
#     'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': '1.3 Tracking Progress to the Energy Moonshot',
#     'progress': 'not_started'},
#    {'cta': 'Go to the lesson',
#     'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': '1.4 Opportunities for Digitalization and AI',
#     'progress': 'not_started'},
#    {'cta': 'Go to the lesson',
#     'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': 'Module conclusion',
#     'progress': 'not_started'}]}}

# %%
node = chapter_intro.select_node("FRAME", "connection_next")
print(node)
# Out:
# | FRAME (connection_next)
# |- GROUP (Decoratives_ignore)
# |-- RECTANGLE (Background image)
# |- FRAME (Decoratives_ignore)
# |-- FRAME (Frame 1171277114)
# |--- FRAME (Button/Primary)
# |---- VECTOR (Path 637)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- TEXT (title)
# |- TEXT (cta)

# %%
frame = sea.ConnectionNext.from_node(node)
frame.to_content()
# Out:
# {'id': 'connection_next',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': 'Next up',
#   'title': 'Chapter 1: Introduction to the Energy Transition Landscape',
#   'cta': 'Start learning'}}

# %% [markdown]
# #### Lesson

# %%
lesson = chapter.select_node("SECTION", "Lesson 1.1")
print(lesson)
# Out:
# | SECTION (Lesson 1.1)
# |- FRAME (lesson_cover)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- GROUP (decoratives_ignore)
# |--- LINE (Line 269_ignore)
# |-- GROUP (lesson)
# |--- TEXT (label)
# |--- TEXT (number)
# |-- TEXT (title)
# |- FRAME (quote_large_with_name)
# |-- TEXT (quote)
# |-- TEXT (author)
# |-- GROUP (Decoratives_ignore)
# |--- VECTOR (Vector 275)
# |- FRAME (key_takeaways)
# |-- TEXT (title)
# |-- TEXT (intro)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (nature)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (objectives)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |--- TEXT (title)
# |--- TEXT (description)
# |-- GROUP (decoratives_ignore)
# |--- TEXT (1.)
# |--- TEXT (2)
# |--- TEXT (3.)
# |- FRAME (key_resources)
# |-- TEXT (title)
# |-- GROUP (resources)
# |--- RECTANGLE (image)
# |--- TEXT (text)
# |-- GROUP (resources)
# |--- RECTANGLE (image_3)
# |--- TEXT (text)
# |-- GROUP (resources)
# |--- RECTANGLE (image_3)
# |--- TEXT (Renewable Innovations in the Public and Private Sector)
# |- FRAME (connection_next)
# |-- FRAME (Decoratives_ignore)
# |--- RECTANGLE (nature)
# |--- FRAME (Frame 1171277078)
# |---- FRAME (Frame 1171277114)
# |----- FRAME (Frame 1171277313)
# |----- FRAME (Button/Primary)
# |------ FRAME (Chevrons / Chevron small right)
# |------- VECTOR (Path 637)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)
# |- FRAME (lesson_part_cover)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- GROUP (decoratives_ignore)
# |--- LINE (Line 269_ignore)
# |-- TEXT (title)
# |- FRAME (photo-vertical)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (caption)
# |-- GROUP (decorative_ignore)
# |--- VECTOR (Vector 275)
# |- FRAME (text)
# |-- GROUP (subtitle)
# |--- TEXT (text)
# |-- GROUP (subtitle_small)
# |--- TEXT (text)
# |-- GROUP (paragraph_large)
# |--- TEXT (text)
# |- FRAME (key_concepts)
# |-- TEXT (title)
# |-- TEXT (intro)
# |-- GROUP (decoratives_ignore)
# |--- FRAME (Modules/bulletpoint)
# |--- FRAME (Modules/bulletpoint)
# |--- FRAME (Modules/bulletpoint)
# |--- VECTOR (Vector 275)
# |-- GROUP (concepts)
# |--- TEXT (title)
# |--- TEXT (body)
# |-- GROUP (concepts)
# |--- TEXT (title)
# |--- TEXT (body)
# |-- GROUP (concepts)
# |--- TEXT (title)
# |--- TEXT (body)
# |--- TEXT (source)

# %%
node = lesson.select_node("FRAME", "lesson_cover")
print(node)
# Out:
# | FRAME (lesson_cover)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- GROUP (decoratives_ignore)
# |-- LINE (Line 269_ignore)
# |- GROUP (lesson)
# |-- TEXT (label)
# |-- TEXT (number)
# |- TEXT (title)

# %%
frame = sea.Cover.from_node(node)
frame.to_content()
# Out:
# {'id': 'lesson_cover',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': {'label': 'Lesson', 'number': '1'},
#   'title': 'Energy data, in planning, monitoring, and evaluation',
#   'cta': None}}

# %%
node = lesson.select_node("FRAME", "text")
print(node)
# Out:
# | FRAME (text)
# |- GROUP (subtitle)
# |-- TEXT (text)
# |- GROUP (subtitle_small)
# |-- TEXT (text)
# |- GROUP (paragraph_large)
# |-- TEXT (text)

# %%
frame = sea.ModuleText.from_node(node)
frame.to_content()
# Out:
# {'id': 'text',
#  'colorscheme': 'dark',
#  'content': {'content': [{'id': 'subtitle',
#     'colorscheme': None,
#     'text': 'Lesson 1 Overview'},
#    {'id': 'subtitle_small',
#     'colorscheme': None,
#     'text': 'Lorem ipsum dolor sit amet'},
#    {'id': 'paragraph_large',
#     'colorscheme': None,
#     'text': 'This module provides a comprehensive understanding of the importance of data in planning, monitoring, and evaluation (PM&E) in the context of sustainable energy. It emphasizes the role of data in informing evidence-based decision-making, supporting energy policy formulation, and tracking progress toward sustainable energy goals. The module also explores the challenges associated with data quality and availability, as well as the ethical considerations related to data collection and sharing.'}]}}

# %%
node = lesson.select_node("FRAME", "key_concepts")
print(node)
# Out:
# | FRAME (key_concepts)
# |- TEXT (title)
# |- TEXT (intro)
# |- GROUP (decoratives_ignore)
# |-- FRAME (Modules/bulletpoint)
# |-- FRAME (Modules/bulletpoint)
# |-- FRAME (Modules/bulletpoint)
# |-- VECTOR (Vector 275)
# |- GROUP (concepts)
# |-- TEXT (title)
# |-- TEXT (body)
# |- GROUP (concepts)
# |-- TEXT (title)
# |-- TEXT (body)
# |- GROUP (concepts)
# |-- TEXT (title)
# |-- TEXT (body)
# |-- TEXT (source)

# %%
frame = sea.KeyConcepts.from_node(node)
frame.to_content()
# Out:
# {'id': 'key_concepts',
#  'colorscheme': 'dark',
#  'content': {'title': 'Key concepts',
#   'intro': 'If you only have space to remember 3 things:',
#   'concepts': [{'title': 'Just Transition',
#     'body': '“Greening the economy in a way that is as fair and inclusive as possible to everyone concerned, creating decent work opportunities and leaving no one behind.”',
#     'source': None},
#    {'title': '\rNet Zero',
#     'body': 'Put simply, net zero means cutting carbon emissions to a small amount of residual emissions that can be absorbed and durably stored by nature and other carbon dioxide removal measures, leaving zero in the atmosphere.',
#     'source': None},
#    {'title': 'Inclusive Access',
#     'body': 'Lorem ipsum dolor sit amet consectetur. Amet aenean rhoncus cursus lectus quis non tortor ultricies. Facilisis faucibus massa urna lorem sit sit.',
#     'source': 'Lorem ipsum dolor sit'}]}}

# %%
node = lesson.select_node("FRAME", "lesson_part_cover")
print(node)
# Out:
# | FRAME (lesson_part_cover)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- GROUP (decoratives_ignore)
# |-- LINE (Line 269_ignore)
# |- TEXT (title)

# %%
frame = sea.Cover.from_node(node)
frame.to_content()
# Out:
# {'id': 'lesson_part_cover',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': 'M1: Just Energy Transition | chapter 1 | Lesson 1 | Part 1',
#   'title': 'Part 1: How the triptych of data, digital, and AI are transforming energy policy and planning',
#   'cta': None}}

# %%
node = lesson.select_node("FRAME", "photo-vertical")
print(node)
# Out:
# | FRAME (photo-vertical)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (caption)
# |- GROUP (decorative_ignore)
# |-- VECTOR (Vector 275)

# %%
frame = sea.PhotoVertical.from_node(node)
frame.to_content()
# Out:
# {'id': 'photo_vertical',
#  'colorscheme': 'light',
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None}}}

# %%
node = lesson.select_node("FRAME", "quote_large_with_name")
print(node)
# Out:
# | FRAME (quote_large_with_name)
# |- TEXT (quote)
# |- TEXT (author)
# |- GROUP (Decoratives_ignore)
# |-- VECTOR (Vector 275)

# %%
frame = sea.Quote.from_node(node)
frame.to_content()
# Out:
# {'id': 'quote_large_with_name',
#  'colorscheme': None,
#  'content': {'quote': 'UNDP defines data-driven decision-making as “the process of using data to inform your decision-making process and validate a course of action before committing to it”.',
#   'author': 'Name Surname'}}

# %%
node = lesson.select_node("FRAME", "key_takeaways")
print(node)
# Out:
# | FRAME (key_takeaways)
# |- TEXT (title)
# |- TEXT (intro)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (nature)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (objectives)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (title)
# |-- TEXT (description)
# |- GROUP (decoratives_ignore)
# |-- TEXT (1.)
# |-- TEXT (2)
# |-- TEXT (3.)

# %%
frame = sea.LearningObjectives.from_node(node)
frame.to_content()
# Out:
# {'id': 'key_takeaways',
#  'colorscheme': None,
#  'content': {'title': 'Learning Objectives',
#   'intro': 'If you only have space to remember 3 things:',
#   'cards': [{'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': 'Monitoring progress towards sustainable energy goals\xa0is key.',
#     'description': "Monitoring the evolution of key indicators, such as the renewable energy share in total final energy consumption (e.g., indicator 7.2.1), provides vital insights into the progress toward sustainable energy goals. This data-driven approach enhances countries' ability to plan scenarios effectively in line with achieving global energy targets by 2030."},
#    {'image': {'src': 'nature', 'caption': 'image caption', 'url': None},
#     'title': 'Economic growth and energy policies\xa0are critical.',
#     'description': 'Data-driven analysis offers valuable evidence regarding the economic impacts of different energy policies, including effects on GDP, employment rates, and trade balances. Energy modellling, encompassing various methodologies such as econometric analysis and technology-rich accounting frameworks, serves as a crucial component in informing energy policy formulation.'},
#    {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#     'title': 'We must always be evaluating the environmental impact of sustainable energy development.',
#     'description': 'Integration of data on sustainable energy development with environmental datasets enables comprehensive assessments of environmental impacts and facilitates the monitoring of changes over time.'}]}}

# %%
# the structure isn't right, parsing is not implemented
node = lesson.select_node("FRAME", "key_resources")
print(node)
# Out:
# | FRAME (key_resources)
# |- TEXT (title)
# |- GROUP (resources)
# |-- RECTANGLE (image)
# |-- TEXT (text)
# |- GROUP (resources)
# |-- RECTANGLE (image_3)
# |-- TEXT (text)
# |- GROUP (resources)
# |-- RECTANGLE (image_3)
# |-- TEXT (Renewable Innovations in the Public and Private Sector)

# %%
node = lesson.select_node("FRAME", "connection_next")
print(node)
# Out:
# | FRAME (connection_next)
# |- FRAME (Decoratives_ignore)
# |-- RECTANGLE (nature)
# |-- FRAME (Frame 1171277078)
# |--- FRAME (Frame 1171277114)
# |---- FRAME (Frame 1171277313)
# |---- FRAME (Button/Primary)
# |----- FRAME (Chevrons / Chevron small right)
# |------ VECTOR (Path 637)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- TEXT (title)
# |- TEXT (cta)

# %%
frame = sea.ConnectionNext.from_node(node)
frame.to_content()
# Out:
# {'id': 'connection_next',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': 'Return to',
#   'title': 'Chapter: \u2028Geospatial Data in Electrification planning and policy',
#   'cta': 'Back'}}

# %% [markdown]
# #### Chapter Outro

# %%
chapter_outro = chapter.select_node("SECTION", "Chapter 1 Outro")
print(chapter_outro)
# Out:
# | SECTION (Chapter 1 Outro)
# |- FRAME (chapter_outro)
# |-- FRAME (Decoratives_ignore)
# |--- FRAME (Frame)
# |---- FRAME (Button/Primary)
# |----- FRAME (Chevrons / Chevron small right)
# |------ VECTOR (Path 637)
# |--- FRAME (Separator)
# |--- VECTOR (Vector 289)
# |-- TEXT (intro)
# |-- GROUP (quiz)
# |--- TEXT (intro)
# |--- TEXT (title)
# |--- TEXT (cta)
# |--- TEXT (buttonCta)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |-- GROUP (title)
# |--- TEXT (second_line)
# |--- TEXT (first_line)
# |-- TEXT (subtitle)
# |-- TEXT (body)
# |- FRAME (connection_next)
# |-- GROUP (Decoratives_ignore)
# |--- RECTANGLE (nature)
# |--- FRAME (Frame 1171277078)
# |---- FRAME (Frame 1171277114)
# |----- FRAME (Button/Primary)
# |------ FRAME (Chevrons / Chevron small right)
# |------- VECTOR (Path 637)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)

# %%
node = chapter_outro.select_node("FRAME", "chapter_outro")
print(node)
# Out:
# | FRAME (chapter_outro)
# |- FRAME (Decoratives_ignore)
# |-- FRAME (Frame)
# |--- FRAME (Button/Primary)
# |---- FRAME (Chevrons / Chevron small right)
# |----- VECTOR (Path 637)
# |-- FRAME (Separator)
# |-- VECTOR (Vector 289)
# |- TEXT (intro)
# |- GROUP (quiz)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)
# |-- TEXT (buttonCta)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |- GROUP (title)
# |-- TEXT (second_line)
# |-- TEXT (first_line)
# |- TEXT (subtitle)
# |- TEXT (body)

# %%
frame = sea.Outro.from_node(node)
frame.to_content()
# Out:
# {'id': 'chapter_outro',
#  'colorscheme': None,
#  'content': {'intro': 'This concludes',
#   'title': 'Chapter 1 Chapter 1',
#   'subtitle': 'Lorem ipsum dolor sit amet consectetur',
#   'body': 'Thank you for joining us for the third chapter of the Just Energy Transition Module. We invite you to interact with the closing scenario, and to reflect on how you can take action to move these ideas from ambitions into action.',
#   'next_block': {'intro': 'Interactive Scenario ',
#    'title': 'Title of the scenario',
#    'cta': 'You have a meeting with the minister of energy to discuss data-driven policy. Are you ready?',
#    'button_cta': 'Launch the interactive scenario',
#    'image': {'src': 'src', 'caption': 'image caption', 'url': None}}}}

# %%
node = chapter_outro.select_node("FRAME", "connection_next")
print(node)
# Out:
# | FRAME (connection_next)
# |- GROUP (Decoratives_ignore)
# |-- RECTANGLE (nature)
# |-- FRAME (Frame 1171277078)
# |--- FRAME (Frame 1171277114)
# |---- FRAME (Button/Primary)
# |----- FRAME (Chevrons / Chevron small right)
# |------ VECTOR (Path 637)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- TEXT (title)
# |- TEXT (cta)

# %%
frame = sea.ConnectionNext.from_node(node)
frame.to_content()
# Out:
# {'id': 'connection_next',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': 'Next up',
#   'title': 'Module 1 Wrapup: Innovation and Digitalization in the Energy Transition',
#   'cta': 'Start learning'}}

# %% [markdown]
# ### Module Outro

# %%
document.display(depth=2)
# Out:
# | DOCUMENT (Document)
# |- CANVAS (Page 1 (clean ver))
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter, Lesson, and Part)
# |-- SECTION (Module 1 Outro)
# |- CANVAS (Page 2 (Updated strcutrue + notes))
# |-- FRAME (Click <clip content>to hide all comments)
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter 1)
# |-- SECTION (Module 1 Outro)
# |-- SECTION (Templates need to be developed))
# |- CANVAS (Backup (Original Page 1))
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Module 1 Intro)
# |-- SECTION (Chapter 1)
# |-- SECTION (Chapter 2)
# |-- SECTION (Module 1 Outro)
# |-- SECTION (Module 1 Outro)

# %%
module_outro = document.select_node("SECTION", "Module 1 Outro")
print(module_outro)
# Out:
# | SECTION (Module 1 Outro)
# |- FRAME (module_outro)
# |-- TEXT (intro)
# |-- GROUP (Decoratives_ignore)
# |--- FRAME (Decoratives_ignore)
# |---- VECTOR (Vector 289)
# |--- FRAME (Decoratives_ignore)
# |---- FRAME (Decoratives_ignore)
# |----- FRAME (Modules/Paragraph)
# |------ FRAME (Subtitle)
# |------ FRAME (Frame 1171277319)
# |------- FRAME (Subtitle)
# |----- FRAME (Button/Primary)
# |------ FRAME (Chevrons / Chevron small right)
# |------- VECTOR (Path 637)
# |-- GROUP (quiz)
# |--- TEXT (intro)
# |--- TEXT (title)
# |--- TEXT (cta)
# |--- TEXT (buttonCta)
# |--- GROUP (image)
# |---- RECTANGLE (src)
# |---- TEXT (caption)
# |-- GROUP (title)
# |--- TEXT (first_line)
# |--- TEXT (second_line)
# |-- TEXT (subtitle)
# |-- TEXT (body)
# |- FRAME (connection_next)
# |-- GROUP (Decoratives_ignore)
# |--- RECTANGLE (nature)
# |--- FRAME (Frame 1171277078)
# |---- FRAME (Frame 1171277114)
# |----- FRAME (Button/Primary)
# |------ FRAME (Chevrons / Chevron small right)
# |------- VECTOR (Path 637)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)

# %%
node = module_outro.select_node("FRAME", "module_outro")
print(node)
# Out:
# | FRAME (module_outro)
# |- TEXT (intro)
# |- GROUP (Decoratives_ignore)
# |-- FRAME (Decoratives_ignore)
# |--- VECTOR (Vector 289)
# |-- FRAME (Decoratives_ignore)
# |--- FRAME (Decoratives_ignore)
# |---- FRAME (Modules/Paragraph)
# |----- FRAME (Subtitle)
# |----- FRAME (Frame 1171277319)
# |------ FRAME (Subtitle)
# |---- FRAME (Button/Primary)
# |----- FRAME (Chevrons / Chevron small right)
# |------ VECTOR (Path 637)
# |- GROUP (quiz)
# |-- TEXT (intro)
# |-- TEXT (title)
# |-- TEXT (cta)
# |-- TEXT (buttonCta)
# |-- GROUP (image)
# |--- RECTANGLE (src)
# |--- TEXT (caption)
# |- GROUP (title)
# |-- TEXT (first_line)
# |-- TEXT (second_line)
# |- TEXT (subtitle)
# |- TEXT (body)

# %%
frame = sea.Outro.from_node(node)
frame.to_content()
# Out:
# {'id': 'module_outro',
#  'colorscheme': None,
#  'content': {'intro': 'Congratulations, you have concluded',
#   'title': 'Module 1  Module 1 ',
#   'subtitle': 'Lorem ipsum dolor sit amet',
#   'body': 'Thank you for joining us for the third chapter of the Just Energy Transition Module. We invite you to interact with the closing scenario, and to reflect on how you can take action to move these ideas from ambitions into action.',
#   'next_block': {'intro': 'Graded Quiz',
#    'title': 'Title of the quiz',
#    'cta': 'Test your knowledge',
#    'button_cta': 'Launch the Graded Quiz',
#    'image': {'src': 'src', 'caption': 'image caption', 'url': None}}}}

# %%
node = module_outro.select_node("FRAME", "connection_next")
print(node)
# Out:
# | FRAME (connection_next)
# |- GROUP (Decoratives_ignore)
# |-- RECTANGLE (nature)
# |-- FRAME (Frame 1171277078)
# |--- FRAME (Frame 1171277114)
# |---- FRAME (Button/Primary)
# |----- FRAME (Chevrons / Chevron small right)
# |------ VECTOR (Path 637)
# |- GROUP (image)
# |-- RECTANGLE (src)
# |-- TEXT (caption)
# |- TEXT (intro)
# |- TEXT (title)
# |- TEXT (cta)

# %%
frame = sea.ConnectionNext.from_node(node)
frame.to_content()
# Out:
# {'id': 'connection_next',
#  'colorscheme': None,
#  'content': {'image': {'src': 'src', 'caption': 'image caption', 'url': None},
#   'intro': 'Next up',
#   'title': 'Module 2: Innovation and Digitalization in the Energy Transition',
#   'cta': 'Start learning'}}
