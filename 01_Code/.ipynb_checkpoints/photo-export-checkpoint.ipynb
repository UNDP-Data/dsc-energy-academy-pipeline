# %%
import os
import requests
from PIL import Image
import io
import base64
import asyncio
from typing import Literal
from dotenv import load_dotenv
from urllib.parse import urlparse
from itertools import islice

from azure.storage.blob import ContentSettings
from azure.storage.blob.aio import ContainerClient
from azure.core.pipeline.transport import AioHttpTransport

# === Load environment ===
import json
import os
import requests
from dotenv import load_dotenv

load_dotenv(".env")

FIGMA_TOKEN = os.getenv("FIGMA_TOKEN")
FILE_ID_1 = os.getenv("FIGMA_DOCUMENT_ID1")
FILE_ID_2 = os.getenv("FIGMA_DOCUMENT_ID2")

pages_1 = ["Module 1", "Module 2", "Module 3", "Module 4"]
pages_2 = ["Module 5", "Module 6", "Module 7", "Module 8"]

SAS_URL = os.getenv("SAS_URL")

# === SSL override toggle ===
USE_INSECURE_SSL = False

# === Sanity check ===
missing = [var for var in ["FIGMA_TOKEN", "FILE_ID_1", "FILE_ID_2", "SAS_URL"] if not globals()[var]]
if missing:
    raise EnvironmentError(f"Missing required environment variables: {', '.join(missing)}")

def convert_to_thumbnail(base64_str: str, resize_to=1080, target_format="webp", lossless=False, quality=95) -> bytes:
    """
    Convert base64 image string to resized WebP thumbnail (1080p max).
    """
    image_bytes = base64.b64decode(base64_str)
    with Image.open(io.BytesIO(image_bytes)) as img:
        img = img.convert("RGB")
        if img.width > resize_to or img.height > resize_to:
            img.thumbnail((resize_to, resize_to), Image.Resampling.LANCZOS)
        output = io.BytesIO()
        if lossless:
            img.save(output, format=target_format.upper(), lossless=True)
        else:
            img.save(output, format=target_format.upper(), quality=quality)
        return output.getvalue()



# === Figma Image ID Extraction ===
def get_image_ids(file_id: str, token: str, pages: list[str]) -> dict[str, list[str]]:
    url = f"https://api.figma.com/v1/files/{file_id}"
    headers = {"X-Figma-Token": token}
    res = requests.get(url, headers=headers)
    res.raise_for_status()
    data = res.json()

    results = {}

    def collect_image_fills(node, found):
        if "fills" in node:
            for fill in node["fills"]:
                if fill.get("type") == "IMAGE":
                    found.append(node["id"])
                    break
        for child in node.get("children", []):
            collect_image_fills(child, found)

    for page in data["document"]["children"]:
        if page["name"] in pages:
            found = []
            collect_image_fills(page, found)
            results[page["name"]] = found

    return results


# === Upload to Azure ===
async def upload_image_to_azure(entity_id: str, page_name: str, image_data: bytes, overwrite: bool = False) -> str:
    folder_path = f"{page_name.replace(' ', '_')}"
    blob_name = f"{folder_path}/{entity_id}.webp"

    if USE_INSECURE_SSL:
        import ssl
        ssl_context = ssl.create_default_context()
        ssl_context.check_hostname = False
        ssl_context.verify_mode = ssl.CERT_NONE
        transport = AioHttpTransport(ssl_context=ssl_context)
        client = ContainerClient.from_container_url(SAS_URL, transport=transport)
    else:
        client = ContainerClient.from_container_url(SAS_URL)

    async with client:
        blob_client = client.get_blob_client(blob_name)
        blob_exists = await blob_client.exists()

        if blob_exists and not overwrite:
            print(f"⏭️ Skipped {entity_id} (already exists)")
            return blob_client.url.split("?")[0]

        await blob_client.upload_blob(
            data=image_data,
            overwrite=True,
            blob_type="BlockBlob",
            content_settings=ContentSettings(content_type="image/webp"),
        )
        return blob_client.url.split("?")[0]



# === Process Each Page ===
async def upload_figma_images_to_azure(
    file_id: str,
    page_name: str,
    node_ids: list[str],
    overwrite: bool = False
):
    if not node_ids:
        print(f"⚠️ No images found in page: {page_name}")
        return

    headers = {"X-Figma-Token": FIGMA_TOKEN}

    
    def chunked(iterable, size):
        it = iter(iterable)
        while True:
            chunk = list(islice(it, size))
            if not chunk:
                break
            yield chunk
    
    image_urls = {}
    
    for batch in chunked(node_ids, 20):
        try:
            res = requests.get(
                f"https://api.figma.com/v1/images/{file_id}",
                params={"ids": ",".join(batch), "format": "png"},
                headers=headers,
                timeout=60,
            )
            res.raise_for_status()
            image_urls.update(res.json().get("images", {}))
        except Exception as e:
            print(f"❌ Failed to fetch batch from Figma: {e}")


    for node_id in reversed(node_ids):
        url = image_urls.get(node_id)
        try:
            img_res = requests.get(url)
            img_res.raise_for_status()
            binary = img_res.content
            base64_img = base64.b64encode(binary).decode("utf-8")

            webp_data = convert_to_thumbnail(base64_img, resize_to=1080, target_format="webp", lossless=False, quality=95)
            clean_id = node_id.replace(":", "_")

            blob_url = await upload_image_to_azure(clean_id, "Modules/"+page_name, webp_data, overwrite=overwrite)
            print(f"✅ Uploaded {clean_id} → {blob_url}")

        except Exception as e:
            print(f"❌ Failed to process {node_id}: {e}")


# === Pipeline Runner ===
async def run_pipeline(overwrite):

    images_1 = get_image_ids(FILE_ID_1, FIGMA_TOKEN, pages_1)
    images_2 = get_image_ids(FILE_ID_2, FIGMA_TOKEN, pages_2)

    for page, ids in images_1.items():
        print(f"\n📦 Processing {page} from FILE_ID_1...")
        await upload_figma_images_to_azure(FILE_ID_1, page, ids, overwrite=overwrite)

    for page, ids in images_2.items():
        print(f"\n📦 Processing {page} from FILE_ID_2...")
        await upload_figma_images_to_azure(FILE_ID_2, page, ids, overwrite=overwrite)

# %%
 #=== Run in notebook or script ===
await run_pipeline(overwrite=False)
# Out:
# 📦 Processing Module 1 from FILE_ID_1...
# ⏭️ Skipped 481_940 (already exists)
# ✅ Uploaded 481_940 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_940.webp
# ⏭️ Skipped 481_925 (already exists)
# ✅ Uploaded 481_925 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_925.webp
# ⏭️ Skipped 481_920 (already exists)
# ✅ Uploaded 481_920 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_920.webp
# ⏭️ Skipped 481_915 (already exists)
# ✅ Uploaded 481_915 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_915.webp
# ⏭️ Skipped 481_910 (already exists)
# ✅ Uploaded 481_910 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_910.webp
# ⏭️ Skipped 481_905 (already exists)
# ✅ Uploaded 481_905 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_905.webp
# ⏭️ Skipped 481_946 (already exists)
# ✅ Uploaded 481_946 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_946.webp
# ⏭️ Skipped 481_1406 (already exists)
# ✅ Uploaded 481_1406 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/481_1406.webp
# ⏭️ Skipped 488_102 (already exists)
# ✅ Uploaded 488_102 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/488_102.webp
# ⏭️ Skipped 580_110 (already exists)
# ✅ Uploaded 580_110 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/580_110.webp
# ⏭️ Skipped 1070_5 (already exists)
# ✅ Uploaded 1070_5 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/1070_5.webp
# ⏭️ Skipped 488_71 (already exists)
# ✅ Uploaded 488_71 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/488
→ https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_134.webp
# ⏭️ Skipped 522_129 (already exists)
# ✅ Uploaded 522_129 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_129.webp
# ⏭️ Skipped 522_319 (already exists)
# ✅ Uploaded 522_319 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_319.webp
# ⏭️ Skipped 522_537 (already exists)
# ✅ Uploaded 522_537 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_537.webp
# ⏭️ Skipped 527_28 (already exists)
# ✅ Uploaded 527_28 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/527_28.webp
# ⏭️ Skipped 522_550 (already exists)
# ✅ Uploaded 522_550 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_550.webp
# ⏭️ Skipped 527_39 (already exists)
# ✅ Uploaded 527_39 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/527_39.webp
# ⏭️ Skipped 527_47 (already exists)
# ✅ Uploaded 527_47 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/527_47.webp
# ⏭️ Skipped 609_328 (already exists)
# ✅ Uploaded 609_328 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/609_328.webp
# ⏭️ Skipped 527_67 (already exists)
# ✅ Uploaded 527_67 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/527_67.webp
# ⏭️ Skipped 522_566 (already exists)
# ✅ Uploaded 522_566 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_566.webp
# ⏭️ Skipped 609_331 (already exists)
# ✅ Uploaded 609_331 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/609_331.webp
# ⏭️ Skipped 522_574 (already exists)
# ✅ Uploaded 522_574 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_574.webp
# ⏭️ Skipped 538_664 (already exists)
# ✅ Uploaded 538_664 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/538_664.webp
# ⏭️ Skipped 538_672 (already exists)
# ✅ Uploaded 538_672 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/538_672.webp
# ⏭️ Skipped 522_625 (already exists)
# ✅ Uploaded 522_625 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_625.webp
# ⏭️ Skipped 522_620 (already exists)
# ✅ Uploaded 522_620 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_620.webp
# ⏭️ Skipped 522_610 (already exists)
# ✅ Uploaded 522_610 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/522_610.webp
# ⏭️ Skipped 609_345 (already exists)
# ✅ Uploaded 609_345 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/609_345.webp
# ⏭️ Skipped 556_82 (already exists)
# ✅ Uploaded 556_82 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/556_82.webp
# ⏭️ Skipped 556_122 (already exists)
# ✅ Uploaded 556_122 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/556_122.webp
# ⏭️ Skipped 556_97 (already exists)
# ✅ Uploaded 556_97 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/556_97.webp
# ⏭️ Skipped 556_135 (already exists)
# ✅ Uploaded 556_135 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/556_135.webp
# ⏭️ Skipped 563_161 (already exists)
# ✅ Uploaded 563_161 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/563_161.webp
# ⏭️ Skipped 563_206 (already exists)
# ✅ Uploaded 563_206 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/563_206.webp
# ⏭️ Skipped 563_225 (already exists)
# ✅ Uploaded 563_225 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/563_225.webp
# ⏭️ Skipped 609_399 (already exists)
# ✅ Uploaded 609_399 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/609_399.webp
# ⏭️ Skipped 563_324 (already exists)
# ✅ Uploaded 563_324 → https://sehseadata.blob.core.windows.net/images/Modules/Module_1/563_324.webp
#
# 📦 Processing Module 2 from FILE_ID_1...
# ⏭️ Skipped 316_449 (already exists)
# ✅ Uploaded 316_449 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/316_449.webp
# ⏭️ Skipped 316_432 (already exists)
# ✅ Uploaded 316_432 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/316_432.webp
# ⏭️ Skipped 532_137 (already exists)
# ✅ Uploaded 532_137 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/532_137.webp
# ⏭️ Skipped 532_131 (already exists)
# ✅ Uploaded 532_131 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/532_131.webp
# ⏭️ Skipped 615_581 (already exists)
# ✅ Uploaded 615_581 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2
→ https://sehseadata.blob.core.windows.net/images/Modules/Module_2/653_1740.webp
# ⏭️ Skipped 681_10 (already exists)
# ✅ Uploaded 681_10 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/681_10.webp
# ⏭️ Skipped 654_1761 (already exists)
# ✅ Uploaded 654_1761 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_1761.webp
# ⏭️ Skipped 654_1801 (already exists)
# ✅ Uploaded 654_1801 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_1801.webp
# ⏭️ Skipped 654_1853 (already exists)
# ✅ Uploaded 654_1853 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_1853.webp
# ⏭️ Skipped 654_1848 (already exists)
# ✅ Uploaded 654_1848 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_1848.webp
# ⏭️ Skipped 654_1843 (already exists)
# ✅ Uploaded 654_1843 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_1843.webp
# ⏭️ Skipped 316_124 (already exists)
# ✅ Uploaded 316_124 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/316_124.webp
# ⏭️ Skipped 406_2588 (already exists)
# ✅ Uploaded 406_2588 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/406_2588.webp
# ⏭️ Skipped 654_2271 (already exists)
# ✅ Uploaded 654_2271 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2271.webp
# ⏭️ Skipped 654_2265 (already exists)
# ✅ Uploaded 654_2265 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2265.webp
# ⏭️ Skipped 654_2259 (already exists)
# ✅ Uploaded 654_2259 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2259.webp
# ⏭️ Skipped 406_2717 (already exists)
# ✅ Uploaded 406_2717 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/406_2717.webp
# ⏭️ Skipped 406_2682 (already exists)
# ✅ Uploaded 406_2682 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/406_2682.webp
# ⏭️ Skipped 654_2280 (already exists)
# ✅ Uploaded 654_2280 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2280.webp
# ⏭️ Skipped 654_2286 (already exists)
# ✅ Uploaded 654_2286 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2286.webp
# ⏭️ Skipped 654_2292 (already exists)
# ✅ Uploaded 654_2292 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2292.webp
# ⏭️ Skipped 654_2303 (already exists)
# ✅ Uploaded 654_2303 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/654_2303.webp
# ⏭️ Skipped 665_2317 (already exists)
# ✅ Uploaded 665_2317 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/665_2317.webp
# ⏭️ Skipped 665_2327 (already exists)
# ✅ Uploaded 665_2327 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/665_2327.webp
# ⏭️ Skipped 406_2875 (already exists)
# ✅ Uploaded 406_2875 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/406_2875.webp
# ⏭️ Skipped 406_2872 (already exists)
# ✅ Uploaded 406_2872 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/406_2872.webp
# ⏭️ Skipped 415_124 (already exists)
# ✅ Uploaded 415_124 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/415_124.webp
# ⏭️ Skipped 666_2361 (already exists)
# ✅ Uploaded 666_2361 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2361.webp
# ⏭️ Skipped 666_2377 (already exists)
# ✅ Uploaded 666_2377 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2377.webp
# ⏭️ Skipped 666_2386 (already exists)
# ✅ Uploaded 666_2386 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2386.webp
# ⏭️ Skipped 666_2390 (already exists)
# ✅ Uploaded 666_2390 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2390.webp
# ⏭️ Skipped 666_2400 (already exists)
# ✅ Uploaded 666_2400 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2400.webp
# ⏭️ Skipped 666_2404 (already exists)
# ✅ Uploaded 666_2404 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2404.webp
# ⏭️ Skipped 666_2568 (already exists)
# ✅ Uploaded 666_2568 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/666_2568.webp
# ⏭️ Skipped 667_2580 (already exists)
# ✅ Uploaded 667_2580 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/667_2580.webp
# ⏭️ Skipped 667_2589 (already exists)
# ✅ Uploaded 667_2589 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/667_2589.webp
# ⏭️ Skipped 667_2603 (already exists)
# ✅ Uploaded 667_2603 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2
→ https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_4.webp
# ⏭️ Skipped 470_1615 (already exists)
# ✅ Uploaded 470_1615 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/470_1615.webp
# ⏭️ Skipped 673_29 (already exists)
# ✅ Uploaded 673_29 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_29.webp
# ⏭️ Skipped 673_36 (already exists)
# ✅ Uploaded 673_36 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_36.webp
# ⏭️ Skipped 673_50 (already exists)
# ✅ Uploaded 673_50 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_50.webp
# ⏭️ Skipped 673_73 (already exists)
# ✅ Uploaded 673_73 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_73.webp
# ⏭️ Skipped 673_67 (already exists)
# ✅ Uploaded 673_67 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_67.webp
# ⏭️ Skipped 673_61 (already exists)
# ✅ Uploaded 673_61 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_61.webp
# ⏭️ Skipped 519_323 (already exists)
# ✅ Uploaded 519_323 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/519_323.webp
# ⏭️ Skipped 519_369 (already exists)
# ✅ Uploaded 519_369 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/519_369.webp
# ⏭️ Skipped 673_255 (already exists)
# ✅ Uploaded 673_255 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_255.webp
# ⏭️ Skipped 519_356 (already exists)
# ✅ Uploaded 519_356 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/519_356.webp
# ⏭️ Skipped 673_262 (already exists)
# ✅ Uploaded 673_262 → https://sehseadata.blob.core.windows.net/images/Modules/Module_2/673_262.webp
# ⏭️ Skipped 673_269 (already exists)
# ...
# ✅ Uploaded 2081_696 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2081_696.webp
# ⏭️ Skipped 2081_691 (already exists)
# ✅ Uploaded 2081_691 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2081_691.webp
# ⏭️ Skipped 2081_686 (already exists)
# ✅ Uploaded 2081_686 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2081_686.webp
# ⏭️ Skipped 2072_233 (already exists)
# ✅ Uploaded 2072_233 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2072_233.webp
# ⏭️ Skipped 2072_221 (already exists)
# ✅ Uploaded 2072_221 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2072_221.webp
# ⏭️ Skipped 2084_1354 (already exists)
# ✅ Uploaded 2084_1354 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2084_1354.webp
# ⏭️ Skipped 2084_1349 (already exists)
# ✅ Uploaded 2084_1349 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2084_1349.webp
# ⏭️ Skipped 2084_1344 (already exists)
# ✅ Uploaded 2084_1344 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2084_1344.webp
# ⏭️ Skipped 2084_1330 (already exists)
# ✅ Uploaded 2084_1330 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2084_1330.webp
# ⏭️ Skipped 2084_1318 (already exists)
# ✅ Uploaded 2084_1318 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2084_1318.webp
# ⏭️ Skipped 2595_471 (already exists)
# ✅ Uploaded 2595_471 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_471.webp
# ⏭️ Skipped 2595_455 (already exists)
# ✅ Uploaded 2595_455 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_455.webp
# ⏭️ Skipped 2595_448 (already exists)
# ✅ Uploaded 2595_448 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_448.webp
# ⏭️ Skipped 2595_411 (already exists)
# ✅ Uploaded 2595_411 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_411.webp
# ⏭️ Skipped 2595_391 (already exists)
# ✅ Uploaded 2595_391 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_391.webp
# ⏭️ Skipped 2595_368 (already exists)
# ✅ Uploaded 2595_368 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_368.webp
# ⏭️ Skipped 2595_360 (already exists)
# ✅ Uploaded 2595_360 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2595_360.webp
# ⏭️ Skipped 2072_127 (already exists)
# ✅ Uploaded 2072_127 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2072_127.webp
# ⏭️ Skipped 2155_809 (already exists)
# ✅ Uploaded 2155_809 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2155_809.webp
# ⏭️ Skipped 2112_978 (already exists)
# ✅ Uploaded 2112_978 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/
→ https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2637_60.webp
# ⏭️ Skipped 2252_398 (already exists)
# ✅ Uploaded 2252_398 → https://sehseadata.blob.core.windows.net/images/Modules/Module_8/2252_398.webp

# %%
import json
import os
import re
import base64
import requests
from itertools import islice
from azure.storage.blob.aio import ContainerClient

FIGMA_TOKEN = os.environ["FIGMA_TOKEN"]
SAS_URL = os.environ["SAS_URL"]

def get_container_client() -> ContainerClient:
    return ContainerClient.from_container_url(SAS_URL)

async def blob_exists(blob_name: str, folder: str) -> bool:
    client: ContainerClient = get_container_client()
    blob_path = f"{folder}/{blob_name}.webp"
    try:
        async with client:
            blob_client = client.get_blob_client(blob_path)
            return await blob_client.exists()
    except Exception:
        return False

def get_cover_and_image_node_ids(frame):
    """
    Return (frame_id, inner_image_rectangle_id) for lesson_cover or lesson_subpart_cover frames.
    """
    def find_image_rect(node):
        if node.get("type") == "RECTANGLE":
            for fill in node.get("fills", []):
                if fill.get("type") == "IMAGE":
                    return node.get("id")
        children = node.get("children")
        if isinstance(children, list):
            for child in children:
                found = find_image_rect(child)
                if found:
                    return found
        return None

    if frame.get("type") != "FRAME":
        return None

    if frame.get("name") in {"lesson_cover"}:
        image_node_id = find_image_rect(frame)
        if image_node_id:
            return (frame["id"], image_node_id)
    return None

def chunked(iterable, size):
    it = iter(iterable)
    while True:
        chunk = list(islice(it, size))
        if not chunk:
            break
        yield chunk

async def upload_lesson_cover_images_from_structure(
    figma_json_path: str,
    file_id: str,
    module_structure_path: str,
    known_page_names: list[str],
    overwrite: bool = False
):
    with open(module_structure_path, "r", encoding="utf-8") as f:
        structure = json.load(f)

    with open(figma_json_path, "r", encoding="utf-8") as f:
        figma_data = json.load(f)
    figma_children = figma_data.get("document", {}).get("children", figma_data.get("children", []))

    pages_in_figma = {p.get("name"): p for p in figma_children if p.get("type") == "CANVAS"}
    lesson_to_node = {}

    for page_name in known_page_names:
        figma_page = pages_in_figma.get(page_name)
        if not figma_page:
            print(f"⚠️ Skipping: Page '{page_name}' not found.")
            continue

        module_id_match = re.search(r"Module (\d+)", page_name)
        if not module_id_match:
            print(f"⚠️ Skipping: Could not extract module ID from '{page_name}'.")
            continue
        module_id = module_id_match.group(1)

        module = next((m for m in structure["modules"] if str(m["id"]) == module_id), None)
        if not module:
            print(f"⚠️ Skipping: Module {module_id} not found.")
            continue

        lessons_flat = {
            l["id"]: l
            for c in module.get("chapters", [])
            for l in c.get("lessons", [])
            if not l["id"].endswith(".0") and not l["id"].endswith(".-1")
        }

        for section in figma_page.get("children", []):
            if section.get("type") != "SECTION":
                continue

            chapter_match = re.search(r"Chapter (\d+)", section.get("name", ""))
            if not chapter_match:
                continue
            chapter_num = chapter_match.group(1)

            for subsection in section.get("children", []):
                if subsection.get("type") != "SECTION":
                    continue

                sub_name = subsection.get("name", "")
                match = re.search(r"Lesson (\d+)", sub_name)
                if not match:
                    continue
                lesson_num = match.group(1)
                lesson_id = f"{module_id}.{chapter_num}.{lesson_num}"

                if lesson_id not in lessons_flat:
                    continue

                frames = [f for f in subsection.get("children", []) if f.get("type") == "FRAME"]
                for f in reversed(frames):
                    cover_data = get_cover_and_image_node_ids(f)
                    if cover_data:
                        frame_id, image_id = cover_data
                        lesson_to_node[lesson_id] = {"frame": frame_id, "image": image_id}
                        print(f"✅ Matched lesson {lesson_id} with frame and image")
                        break
                else:
                    print(f"⚠️ No lesson_cover found for {lesson_id}")

    print(f"\n🧠 Found {len(lesson_to_node)} lessons to process")

    # Download image URLs
    all_node_ids = []
    for node_pair in lesson_to_node.values():
        all_node_ids.extend([node_pair["frame"], node_pair["image"]])

    headers = {"X-Figma-Token": FIGMA_TOKEN}
    image_urls = {}

    for batch in chunked(all_node_ids, 20):
        res = requests.get(
            f"https://api.figma.com/v1/images/{file_id}",
            params={"ids": ",".join(batch), "format": "png"},
            headers=headers,
            timeout=60,
        )
        res.raise_for_status()
        image_urls.update(res.json().get("images", {}))

    # Upload to Azure
    for lesson_id, nodes in lesson_to_node.items():
        for kind in ["frame", "image"]:
            node_id = nodes[kind]
            blob_name = f"lesson{lesson_id.replace('.', '')}_{kind}"

            try:
                url = image_urls.get(node_id)
                if not url:
                    raise ValueError("No URL returned for node")

                if not overwrite:
                    already_exists = await blob_exists(blob_name, "Lessons"+"/"+kind)
                    if already_exists:
                        print(f"⏭️ Skipped {blob_name} (already exists)")
                        continue

                img_res = requests.get(url)
                img_res.raise_for_status()
                base64_img = base64.b64encode(img_res.content).decode("utf-8")
                webp_data = convert_to_thumbnail(base64_img, resize_to=1080, target_format="webp")
                blob_url = await upload_image_to_azure(
                    blob_name,
                    "Lessons"+"/"+kind,
                    webp_data,
                    overwrite
                )
                print(f"✅ Uploaded {blob_name} → {blob_url}")
            except Exception as e:
                print(f"❌ Failed to process {blob_name}: {e}")

# %%
# Use this to start upload:
await upload_lesson_cover_images_from_structure(
    figma_json_path="../02_Inputs/figma_jsons/figma_document1.json",
    file_id=FILE_ID_1,
    module_structure_path="../03_Outputs/SEA_Modules/en/module_structure.json",
    known_page_names=pages_1,
    overwrite=True
)

await upload_lesson_cover_images_from_structure(
    figma_json_path="../02_Inputs/figma_jsons/figma_document2.json",
    file_id=FILE_ID_2,
    module_structure_path="../03_Outputs/SEA_Modules/en/module_structure.json",
    known_page_names=pages_2,
    overwrite=True
)
# Out:
# ✅ Matched lesson 1.4.1 with frame and image
# ✅ Matched lesson 1.3.2 with frame and image
# ✅ Matched lesson 1.3.1 with frame and image
# ✅ Matched lesson 1.2.3 with frame and image
# ✅ Matched lesson 1.2.2 with frame and image
# ✅ Matched lesson 1.2.1 with frame and image
# ✅ Matched lesson 1.1.2 with frame and image
# ✅ Matched lesson 1.1.1 with frame and image
# ✅ Matched lesson 2.3.2 with frame and image
# ✅ Matched lesson 2.3.5 with frame and image
# ✅ Matched lesson 2.3.4 with frame and image
# ✅ Matched lesson 2.3.3 with frame and image
# ✅ Matched lesson 2.3.1 with frame and image
# ✅ Matched lesson 2.2.3 with frame and image
# ✅ Matched lesson 2.2.2 with frame and image
# ✅ Matched lesson 2.2.1 with frame and image
# ✅ Matched lesson 2.1.3 with frame and image
# ✅ Matched lesson 2.1.2 with frame and image
# ✅ Matched lesson 2.1.1 with frame and image
# ✅ Matched lesson 3.4.3 with frame and image
# ✅ Matched lesson 3.4.2 with frame and image
# ✅ Matched lesson 3.4.1 with frame and image
# ✅ Matched lesson 3.3.3 with frame and image
# ✅ Matched lesson 3.3.2 with frame and image
# ✅ Matched lesson 3.3.1 with frame and image
# ✅ Matched lesson 3.2.3 with frame and image
# ✅ Matched lesson 3.2.2 with frame and image
# ✅ Matched lesson 3.2.1 with frame and image
# ✅ Matched lesson 3.1.3 with frame and image
# ✅ Matched lesson 3.1.2 with frame and image
# ✅ Matched lesson 3.1.1 with frame and image
# ✅ Matched lesson 4.5.3 with frame and image
# ✅ Matched lesson 4.5.2 with frame and image
# ✅ Matched lesson 4.5.1 with frame and image
# ✅ Matched lesson 4.4.4 with frame and image
# ✅ Matched lesson 4.4.3 with frame and image
# ✅ Matched lesson 4.4.2 with frame and image
# ✅ Matched lesson 4.4.1 with frame and image
# ✅ Matched lesson 4.3.3 with frame and image
# ✅ Matched lesson 4.3.1 with frame and image
# ✅ Matched lesson 4.3.2 with frame and image
# ✅ Matched lesson 4.2.3 with frame and image
# ✅ Matched lesson 4.2.2 with frame and image
# ✅ Matched lesson 4.2.1 with frame and image
# ✅ Matched lesson 4.1.4 with frame and image
# ✅ Matched lesson 4.1.3 with frame and image
# ✅ Matched lesson 4.1.2 with frame and image
# ✅ Matched lesson 4.1.1 with frame and image
#
# 🧠 Found 48 lessons to process
# ✅ Uploaded lesson141_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson141_frame.webp
# ✅ Uploaded lesson141_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson141_image.webp
# ✅ Uploaded lesson132_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson132_frame.webp
# ✅ Uploaded lesson132_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson132_image.webp
# ✅ Uploaded lesson131_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson131_frame.webp
# ✅ Uploaded lesson131_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson131_image.webp
# ✅ Uploaded lesson123_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson123_frame.webp
# ✅ Uploaded lesson123_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson123_image.webp
# ✅ Uploaded lesson122_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson122_frame.webp
# ✅ Uploaded lesson122_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson122_image.webp
# ✅ Uploaded lesson121_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson121_frame.webp
# ✅ Uploaded lesson121_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson121_image.webp
# ✅ Uploaded lesson112_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson112_frame.webp
# ✅ Uploaded lesson112_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson112_image.webp
# ✅ Uploaded lesson111_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson111_frame.webp
# ✅ Uploaded lesson111_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson111_image.webp
# ✅ Uploaded lesson232_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson232_frame.webp
# ✅ Uploaded lesson232_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson232_image.webp
# ✅ Uploaded lesson235_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson235_frame.webp
# ✅ Uploaded lesson235_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson235_image.webp
# ✅ Uploaded lesson234_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson234_frame.webp
# ✅ Uploaded lesson234_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson234_image.webp
# ✅ Uploaded lesson233_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson233_frame.webp
# ✅ Uploaded lesson233_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson233_image.webp
# ✅ Uploaded lesson231_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson231_frame.webp
# ✅ Uploaded lesson231_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson231_image.webp
# ✅ Uploaded lesson223_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson223_frame.webp
# ✅ Uploaded lesson223_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson223_image.webp
# ✅ Uploaded lesson222_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson222_frame.webp
# ✅ Uploaded lesson222_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson222_image.webp
# ✅ Uploaded lesson221_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson221_frame.webp
# ✅ Uploaded lesson221_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson221_image.webp
# ✅ Uploaded lesson213_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson213_frame.webp
# ✅ Uploaded lesson213_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson213_image.webp
# ✅ Uploaded lesson212_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson212_frame.webp
# ✅ Uploaded lesson212_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson212_image.webp
# ✅ Uploaded lesson211_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson211_frame.webp
# ✅ Uploaded lesson211_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson211_image.webp
# ✅ Uploaded lesson343_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson343_frame.webp
# ✅ Uploaded lesson343_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson343_image.webp
# ✅ Uploaded lesson342_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson342_frame.webp
# ✅ Uploaded lesson342_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson342_image.webp
# ✅ Uploaded lesson341_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson341_frame.webp
# ✅ Uploaded lesson341_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson341_image.webp
# ✅ Uploaded lesson333_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson333_frame.webp
# ✅ Uploaded lesson333_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson333_image.webp
# ✅ Uploaded lesson332_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson332_frame.webp
# ✅ Uploaded lesson332_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson332_image.webp
# ✅ Uploaded lesson331_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson331_frame.webp
# ✅ Uploaded lesson331_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson331_image.webp
# ✅ Uploaded lesson323_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson323_frame.webp
# ✅ Uploaded lesson323_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson323_image.webp
# ✅ Uploaded lesson322_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson322_frame.webp
# ✅ Uploaded lesson322_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson322_image.webp
# ✅ Uploaded lesson321_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson321_frame.webp
# ✅ Uploaded lesson321_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson321_image.webp
# ✅ Uploaded lesson313_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson313_frame.webp
# ✅ Uploaded lesson313_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson313_image.webp
# ✅ Uploaded lesson312_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson312_frame.webp
# ✅ Uploaded lesson312_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson312_image.webp
# ✅ Uploaded lesson311_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson311_frame.webp
# ✅ Uploaded lesson311_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson311_image.webp
# ✅ Uploaded lesson453_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson453_frame.webp
# ✅ Uploaded lesson453_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson453_image.webp
# ✅ Uploaded lesson452_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson452_frame.webp
# ✅ Uploaded lesson452_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson452_image.webp
# ✅ Uploaded lesson451_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson451_frame.webp
# ✅ Uploaded lesson451_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson451_image.webp
# ✅ Uploaded lesson444_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson444_frame.webp
# ✅ Uploaded lesson444_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson444_image.webp
# ✅ Uploaded lesson443_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson443_frame.webp
# ✅ Uploaded lesson443_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson443_image.webp
# ✅ Uploaded lesson442_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson442_frame.webp
# ✅ Uploaded lesson442_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson442_image.webp
# ✅ Uploaded lesson441_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson441_frame.webp
# ✅ Uploaded lesson441_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson441_image.webp
# ✅ Uploaded lesson433_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson433_frame.webp
# ✅ Uploaded lesson433_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson433_image.webp
# ✅ Uploaded lesson431_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson431_frame.webp
# ✅ Uploaded lesson431_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson431_image.webp
# ✅ Uploaded lesson432_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson432_frame.webp
# ✅ Uploaded lesson432_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson432_image.webp
# ✅ Uploaded lesson423_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson423_frame.webp
# ✅ Uploaded lesson423_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson423_image.webp
# ✅ Uploaded lesson422_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson422_frame.webp
# ✅ Uploaded lesson422_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson422_image.webp
# ✅ Uploaded lesson421_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson421_frame.webp
# ✅ Uploaded lesson421_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson421_image.webp
# ✅ Uploaded lesson414_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson414_frame.webp
# ✅ Uploaded lesson414_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson414_image.webp
# ✅ Uploaded lesson413_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson413_frame.webp
# ✅ Uploaded lesson413_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson413_image.webp
# ✅ Uploaded lesson412_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson412_frame.webp
# ✅ Uploaded lesson412_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson412_image.webp
# ✅ Uploaded lesson411_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson411_frame.webp
# ✅ Uploaded lesson411_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson411_image.webp
# ✅ Matched lesson 5.4.3 with frame and image
# ✅ Matched lesson 5.4.2 with frame and image
# ✅ Matched lesson 5.4.1 with frame and image
# ✅ Matched lesson 5.3.3 with frame and image
# ✅ Matched lesson 5.3.2 with frame and image
# ✅ Matched lesson 5.3.1 with frame and image
# ✅ Matched lesson 5.2.3 with frame and image
# ✅ Matched lesson 5.2.2 with frame and image
# ✅ Matched lesson 5.2.1 with frame and image
# ✅ Matched lesson 5.1.3 with frame and image
# ✅ Matched lesson 5.1.2 with frame and image
# ✅ Matched lesson 5.1.1 with frame and image
# ✅ Matched lesson 6.4.3 with frame and image
# ✅ Matched lesson 6.4.2 with frame and image
# ✅ Matched lesson 6.4.1 with frame and image
# ✅ Matched lesson 6.3.3 with frame and image
# ✅ Matched lesson 6.3.2 with frame and image
# ✅ Matched lesson 6.3.1 with frame and image
# ✅ Matched lesson 6.2.2 with frame and image
# ✅ Matched lesson 6.2.1 with frame and image
# ✅ Matched lesson 6.1.2 with frame and image
# ✅ Matched lesson 6.1.1 with frame and image
# ✅ Matched lesson 7.4.2 with frame and image
# ✅ Matched lesson 7.4.1 with frame and image
# ✅ Matched lesson 7.3.2 with frame and image
# ✅ Matched lesson 7.3.1 with frame and image
# ✅ Matched lesson 7.2.3 with frame and image
# ✅ Matched lesson 7.2.2 with frame and image
# ✅ Matched lesson 7.2.1 with frame and image
# ✅ Matched lesson 7.1.3 with frame and image
# ✅ Matched lesson 7.1.2 with frame and image
# ✅ Matched lesson 7.1.1 with frame and image
# ✅ Matched lesson 8.3.3 with frame and image
# ✅ Matched lesson 8.3.2 with frame and image
# ✅ Matched lesson 8.3.1 with frame and image
# ✅ Matched lesson 8.2.4 with frame and image
# ✅ Matched lesson 8.2.3 with frame and image
# ✅ Matched lesson 8.2.2 with frame and image
# ✅ Matched lesson 8.2.1 with frame and image
# ✅ Matched lesson 8.1.3 with frame and image
# ✅ Matched lesson 8.1.2 with frame and image
# ✅ Matched lesson 8.1.1 with frame and image
#
# 🧠 Found 42 lessons to process
# ✅ Uploaded lesson543_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson543_frame.webp
# ✅ Uploaded lesson543_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson543_image.webp
# ✅ Uploaded lesson542_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson542_frame.webp
# ✅ Uploaded lesson542_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson542_image.webp
# ✅ Uploaded lesson541_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson541_frame.webp
# ✅ Uploaded lesson541_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson541_image.webp
# ✅ Uploaded lesson533_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson533_frame.webp
# ✅ Uploaded lesson533_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson533_image.webp
# ✅ Uploaded lesson532_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson532_frame.webp
# ✅ Uploaded lesson532_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson532_image.webp
# ✅ Uploaded lesson531_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson531_frame.webp
# ✅ Uploaded lesson531_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson531_image.webp
# ✅ Uploaded lesson523_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson523_frame.webp
# ✅ Uploaded lesson523_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson523_image.webp
# ✅ Uploaded lesson522_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson522_frame.webp
# ✅ Uploaded lesson522_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson522_image.webp
# ✅ Uploaded lesson521_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson521_frame.webp
# ✅ Uploaded lesson521_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson521_image.webp
# ✅ Uploaded lesson513_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson513_frame.webp
# ✅ Uploaded lesson513_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson513_image.webp
# ✅ Uploaded lesson512_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson512_frame.webp
# ✅ Uploaded lesson512_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson512_image.webp
# ✅ Uploaded lesson511_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson511_frame.webp
# ✅ Uploaded lesson511_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson511_image.webp
# ✅ Uploaded lesson643_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson643_frame.webp
# ✅ Uploaded lesson643_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson643_image.webp
# ✅ Uploaded lesson642_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson642_frame.webp
# ✅ Uploaded lesson642_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson642_image.webp
# ✅ Uploaded lesson641_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson641_frame.webp
# ✅ Uploaded lesson641_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson641_image.webp
# ✅ Uploaded lesson633_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson633_frame.webp
# ✅ Uploaded lesson633_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson633_image.webp
# ✅ Uploaded lesson632_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson632_frame.webp
# ✅ Uploaded lesson632_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson632_image.webp
# ✅ Uploaded lesson631_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson631_frame.webp
# ✅ Uploaded lesson631_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson631_image.webp
# ✅ Uploaded lesson622_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson622_frame.webp
# ✅ Uploaded lesson622_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson622_image.webp
# ✅ Uploaded lesson621_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson621_frame.webp
# ✅ Uploaded lesson621_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson621_image.webp
# ✅ Uploaded lesson612_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson612_frame.webp
# ✅ Uploaded lesson612_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson612_image.webp
# ✅ Uploaded lesson611_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson611_frame.webp
# ✅ Uploaded lesson611_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson611_image.webp
# ✅ Uploaded lesson742_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson742_frame.webp
# ✅ Uploaded lesson742_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson742_image.webp
# ✅ Uploaded lesson741_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson741_frame.webp
# ✅ Uploaded lesson741_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson741_image.webp
# ✅ Uploaded lesson732_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson732_frame.webp
# ✅ Uploaded lesson732_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson732_image.webp
# ✅ Uploaded lesson731_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson731_frame.webp
# ✅ Uploaded lesson731_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson731_image.webp
# ✅ Uploaded lesson723_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson723_frame.webp
# ✅ Uploaded lesson723_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson723_image.webp
# ✅ Uploaded lesson722_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson722_frame.webp
# ✅ Uploaded lesson722_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson722_image.webp
# ✅ Uploaded lesson721_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson721_frame.webp
# ✅ Uploaded lesson721_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson721_image.webp
# ✅ Uploaded lesson713_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson713_frame.webp
# ✅ Uploaded lesson713_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson713_image.webp
# ✅ Uploaded lesson712_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson712_frame.webp
# ✅ Uploaded lesson712_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson712_image.webp
# ✅ Uploaded lesson711_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson711_frame.webp
# ✅ Uploaded lesson711_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson711_image.webp
# ✅ Uploaded lesson833_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson833_frame.webp
# ✅ Uploaded lesson833_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson833_image.webp
# ✅ Uploaded lesson832_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson832_frame.webp
# ✅ Uploaded lesson832_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson832_image.webp
# ✅ Uploaded lesson831_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson831_frame.webp
# ✅ Uploaded lesson831_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson831_image.webp
# ✅ Uploaded lesson824_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson824_frame.webp
# ✅ Uploaded lesson824_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson824_image.webp
# ✅ Uploaded lesson823_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson823_frame.webp
# ✅ Uploaded lesson823_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson823_image.webp
# ✅ Uploaded lesson822_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson822_frame.webp
# ✅ Uploaded lesson822_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson822_image.webp
# ✅ Uploaded lesson821_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson821_frame.webp
# ✅ Uploaded lesson821_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson821_image.webp
# ✅ Uploaded lesson813_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson813_frame.webp
# ✅ Uploaded lesson813_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson813_image.webp
# ✅ Uploaded lesson812_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson812_frame.webp
# ✅ Uploaded lesson812_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson812_image.webp
# ✅ Uploaded lesson811_frame → https://sehseadata.blob.core.windows.net/images/Lessons/frame/lesson811_frame.webp
# ✅ Uploaded lesson811_image → https://sehseadata.blob.core.windows.net/images/Lessons/image/lesson811_image.webp
